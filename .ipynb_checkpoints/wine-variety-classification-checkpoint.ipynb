# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


from fastai.text import *
from fastai import *

sns.set_style('darkgrid')
# %matplotlib inline

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


fnames=['/kaggle/input/pretrained-models/lstm_fwd','/kaggle/input/pretrained-models/itos_wt103']
# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/pretrained-models/itos_wt103.pkl
# /kaggle/input/pretrained-models/lstm_fwd.pth
# /kaggle/input/wine-dataset/test.csv
# /kaggle/input/wine-dataset/train.csv

# %% [markdown]
# #  ![](https://img.winespectator.com/wso/bolt/2019-06/1561485468_ww_glassware062519_1600.jpg?imgeng=/w_1600)

# %%
train_data = pd.read_csv('/kaggle/input/wine-dataset/train.csv')
test_data = pd.read_csv('/kaggle/input/wine-dataset/test.csv')
train_data.shape
# Out:
# (82657, 12)

# %% [markdown]
# #  Exploratory Data Analysis

# %%
train_data.head()
# Out:
#        user_name    country  \
# 0            NaN  Australia
# 1  @wawinereport         US
# 2            NaN      Italy
# 3     @vossroger     France
# 4     @vossroger     France
#
#                                         review_title  \
# 0  Andrew Peace 2007 Peace Family Vineyard Chardo...
# 1  North by Northwest 2014 Red (Columbia Valley (...
# 2                  Renato Ratti 2007 Conca  (Barolo)
# 3  Domaine l'Ancienne Cure 2010 L'Abbaye White (B...
# 4  Château du Cèdre 2012 Le Cèdre Vintage Malbec ...
#
#                                   review_description            designation  \
# 0  Classic Chardonnay aromas of apple, pear and h...  Peace Family Vineyard
# 1  This wine is near equal parts Syrah and Merlot...                    NaN
# 2  Barolo Conca opens with inky dark concentratio...                  Conca
# 3  It's impressive what a small addition of Sauvi...               L'Abbaye
# 4  This ripe, sweet wine is rich and full of drie...       Le Cèdre Vintage
#
#    points  price          province                 region_1         region_2  \
# 0      83   10.0   Australia Other  South Eastern Australia              NaN
# 1      89   15.0        Washington     Columbia Valley (WA)  Columbia Valley
# 2      94   80.0          Piedmont                   Barolo              NaN
# 3      87   22.0  Southwest France             Bergerac Sec              NaN
# 4      88   33.0      France Other           Vin de Liqueur              NaN
#
#                     winery                     variety
# 0             Andrew Peace                  Chardonnay
# 1       North by Northwest                   Red Blend
# 2             Renato Ratti                    Nebbiolo
# 3  Domaine l'Ancienne Cure  Bordeaux-style White Blend
# 4         Château du Cèdre                      Malbec

# %%
def nullColumns(train_data):
    list_of_nullcolumns =[]
    for column in train_data.columns:
        total= train_data[column].isna().sum()
        if total !=0:
            print('Total Na values is {0} for column {1}' .format(total, column))
            list_of_nullcolumns.append(column)
    print('\n')
    return list_of_nullcolumns


def percentMissingFeature(data):
    data_na = (data.isnull().sum() / len(data)) * 100
    data_na = data_na.drop(data_na[data_na == 0].index).sort_values(ascending=False)[:30]
    missing_data = pd.DataFrame({'Missing Ratio' :data_na})
    print(missing_data.head(20))
    return data_na


def plotMissingFeature(data_na):
    f, ax = plt.subplots(figsize=(15, 12))
    plt.xticks(rotation='90')
    if(data_na.empty ==False):
        sns.barplot(x=data_na.index, y=data_na)
        plt.xlabel('Features', fontsize=15)
        plt.ylabel('Percent of missing values', fontsize=15)
        plt.title('Percent missing data by feature', fontsize=15)

# %%
train_data_na = percentMissingFeature(train_data)
nullColumns(train_data)
plotMissingFeature(train_data_na)
# Out:
#              Missing Ratio
# region_2         56.508221
# designation      28.608587
# user_name        23.462018
# region_1         15.430030
# price             6.737481
# province          0.042344
# country           0.042344
# Total Na values is 19393 for column user_name
# Total Na values is 35 for column country
# Total Na values is 23647 for column designation
# Total Na values is 5569 for column price
# Total Na values is 35 for column province
# Total Na values is 12754 for column region_1
# Total Na values is 46708 for column region_2

# %%
test_data_na = percentMissingFeature(test_data)
nullColumns(test_data)
plotMissingFeature(test_data_na)
# Out:
#              Missing Ratio
# region_2         56.864263
# designation      28.981369
# user_name        22.927655
# region_1         16.036777
# price             6.745705
# province          0.019356
# country           0.019356
# Total Na values is 4738 for column user_name
# Total Na values is 4 for column country
# Total Na values is 5989 for column designation
# Total Na values is 1394 for column price
# Total Na values is 4 for column province
# Total Na values is 3314 for column region_1
# Total Na values is 11751 for column region_2

# %%
#train_data =  train_data.drop(columns = ['region_2','designation','user_name','price','points'],axis =1)
#test_data =  test_data.drop(columns = ['region_2','designation','user_name','price','points'],axis =1)

# %%
train_data['country'] = train_data['country'].fillna('unknown')
train_data['region_1'] = train_data['region_1'].fillna('unknown')
train_data['province'] = train_data['province'].fillna('unknown')
train_data['price'] =  train_data['price'].fillna(train_data['price'].mean())
train_data['quality/price']  =np.array(np.log1p(train_data['points']))/np.array(np.log1p(train_data['price']))
train_data['value_for_money'] = train_data['quality/price'].apply(lambda val : 'High' if val > 1.5 else ('Medium' if val > 1.0 else 'Low'))

# %% [markdown]
# <font size =8 face ='Times New Roman'>Wines on the basis of their redness and whiteness</font>

# %%
def redness_score(descriptions):
    return (descriptions.count('cherry',re.I) +
           descriptions.count('berry',re.I) +
           descriptions.count('cherries',re.I) +
           descriptions.count('berries',re.I) +
           descriptions.count('red',re.I) +
           descriptions.count('raspberry',re.I) +
           descriptions.count('raspberries',re.I) +
           descriptions.count('blueberry',re.I) +
           descriptions.count('blueberries',re.I)+
           descriptions.count('blackberry',re.I)+
           descriptions.count('blackberries',re.I))


    
def whiteness_score(descriptions):
    return (descriptions.count("lemon",re.I)+
            descriptions.count("lemons",re.I)+
            descriptions.count("lime",re.I)+
            descriptions.count("limes",re.I)+
            descriptions.count("peach",re.I)+
            descriptions.count("peaches",re.I)+
            descriptions.count("white",re.I)+
            descriptions.count("apricot",re.I)+
            descriptions.count("pear",re.I)+
            descriptions.count("apple",re.I)+
            descriptions.count("nectarine",re.I)+
            descriptions.count("orange",re.I)+
            descriptions.count("pineapple",re.I))

# %%
train_data['redness_score'] = train_data['review_description'].apply(lambda r: redness_score(r))
train_data['whiteness_score'] = train_data['review_description'].apply(lambda w: whiteness_score(w))

# %% [markdown]
# <font size =6 face ='Times New Roman' color = #800080>Nebbiolo scores the highest in wine redness score followed by Sangiovese and Red Blend</font>

# %%
wrs = train_data.groupby('variety')['redness_score'].describe().sort_values(by = ['mean'], ascending = False)
f,ax = plt.subplots(figsize = (10,10))
sns.barplot(wrs['mean'],wrs.index)
plt.xticks(fontsize =15)
plt.yticks(fontsize =15)
plt.xlabel("Average Score",fontsize =20)
plt.ylabel("Variety",fontsize =20,rotation = 0)
plt.title('Wines Redness Score', fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# <font size =6 face ='Times New Roman' color = #800080>Riesling scores the highest in whiteness score followed by Pinot Grigio and White Blend</font>

# %%
wws = train_data.groupby('variety')['whiteness_score'].describe().sort_values(by = ['mean'], ascending = False)
f,ax = plt.subplots(figsize = (10,10))
sns.barplot(wws['mean'],wws.index)
plt.xticks(fontsize =15)
plt.yticks(fontsize =15)
plt.xlabel("Average Score",fontsize =20)
plt.ylabel("Variety",fontsize =20,rotation = 0)
plt.title('Wines Whiteness Score', fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# <font size =8 face ='Times New Roman' line-height: 40px>Which are the Costliest Wines?</font>

# %% [markdown]
# <font size =6 face ='Times New Roman' color = #800080 line-height: 40px>Champagne blend and Nebbiolo are the costliest wines</font>

# %%
cwv = train_data.groupby('variety')['price'].describe().sort_values(by = ['mean'], ascending = False)
f,ax = plt.subplots(figsize = (10,10))
sns.barplot(cwv['mean'],cwv.index)
plt.xticks(fontsize =15)
plt.yticks(fontsize =15)
plt.xlabel("Average Price",fontsize =20)
plt.ylabel("Variety",fontsize =20,rotation = 0)
plt.title('Wines Average Cost', fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# <font size =8 face ='Times New Roman'>Which Countries Produce the wines rated highly by sommeliers?</font>

# %% [markdown]
# <font size =5 face ='Times New Roman' color = #800080>India features in top 5 wine producing countries, whose wines are lauded by sommeliers</font>

# %%
hrw = train_data.groupby('country')['points'].describe().sort_values(by = ['mean'], ascending = False)[0:5]
f,ax = plt.subplots(figsize = (10,10))
sns.pointplot(hrw.index,hrw['mean'],sort = False)
plt.xticks(fontsize =15)
plt.yticks(fontsize =15)
plt.xlabel("Country",fontsize =20)
plt.ylabel("Average Points",fontsize =20,rotation = 0)
plt.title('Top 5 Highly Rated Wine Producing countries', fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# <font size =8 face ='Times New Roman'>Which Countries Produce the Costliest wines?</font>

# %% [markdown]
# <font size =5 face ='Times New Roman' color = #800080>
# <li>Europe leads the charge in producing the costliest wines.</li> <br>
# <li>Switzerland is no surprise as it is one of the countries where standard of living is pretty high. This can be attested from the fact that the top 2 countries(Swiss and English) have a huge difference between them</li></font>

# %%
cw = train_data.groupby('country')['price'].describe().sort_values(by = ['mean'], ascending = False)[0:5]
f,ax = plt.subplots(figsize = (10,10))
sns.pointplot(cw.index,cw['mean'],sort = False)
plt.xticks(fontsize =15)
plt.yticks(fontsize =15)
plt.xlabel("Country",fontsize =20)
plt.ylabel("Average Price",fontsize =20,rotation = 0)
plt.title('Top 5 Costliest Wine Producing countries', fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# <font size =8 face ='Times New Roman'>Which countries produce Value for Money wines</font>

# %% [markdown]
# <font size =6 face ='Times New Roman' color = #800080>
#     <li> None of the traditional wine producing countries features in top in this list</li>
# <li>India once again feature in top 5</li></font>

# %%
vfm = train_data.groupby('country')['quality/price'].describe().sort_values(by = ['mean'], ascending = False)[0:10]
f,ax = plt.subplots(figsize = (10,10))
sns.pointplot(vfm.index,vfm['mean'],sort = False,)
plt.xticks(fontsize =15,rotation =90)
plt.yticks(fontsize =15)
plt.xlabel("Country",fontsize =20)
plt.ylabel("Value for Money ",fontsize =20)
plt.title('Top 10 Value for Money Wine Producing countries', fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# <font size =8 face ='Times New Roman'>Which Winery in which Country is the most costliest?</font>

# %%
cw = train_data.groupby(by = ['country','winery'])['price'].describe().sort_values(by = ['mean'], ascending = False)

# %% [markdown]
# <font size =6 face ='Times New Roman' color = #800080 line-height: 40px>France and US, the traditional wine producing countries, as expected make in to this list</font>

# %%
ccw =cw[0:20]
f,ax = plt.subplots(figsize = (20,20))
sns.barplot(ccw.index,ccw['mean'])
plt.xticks(fontsize =15,rotation =90)
plt.yticks(fontsize =15)
plt.xlabel("(Country,Winery)",fontsize =20)
plt.ylabel("Price ",fontsize =20)
plt.title('Costliest Wineries', fontsize=25)
plt.show()

# %% [markdown]
# <font size =8 face ='Times New Roman'>Which winery in which Country is the most economic?</font>

# %% [markdown]
# <font size =6 face ='Times New Roman' color = #800080 line-height: 40px>US mostly has the maximum number of wineries producing cheap wines</font>

# %%
ecw = cw[-20:]
f,ax = plt.subplots(figsize = (20,20))
sns.barplot(ecw.index,ecw['mean'])
plt.xticks(fontsize =15,rotation =90)
plt.yticks(fontsize =15)
plt.xlabel("(Country,Winery)",fontsize =20)
plt.ylabel("Price ",fontsize =20)
plt.title('Economic Wineries', fontsize=25)
plt.show()

# %% [markdown]
# <font size =8 face ='Times New Roman'>Which are the highest rated wines?</font>

# %%
hrv = train_data.groupby('variety')['points'].describe().sort_values(by = ['mean'], ascending = False)[0:5]
f,ax = plt.subplots(figsize = (10,10))
sns.pointplot(hrv.index,hrv['mean'],sort = False)
plt.xticks(fontsize =15,rotation =90)
plt.yticks(fontsize =15)
plt.xlabel("Wines",fontsize =20)
plt.ylabel("Average Points",fontsize =20,rotation = 0)
plt.title('Top 5 Highly Rated Wines', fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# <font size =8 face ='Times New Roman'> What words describe the top 3 highly rated wines?</font>

# %% [markdown]
# <font size =6 face ='Times New Roman' color = #800080 line-height: 40px><li>Nebbiolo seems to be associated  more with the word pepper and spice. I wonder what would it taste like</li><br>
# <li>Grüner Veltliner and Champagne Blend are associated with acidity and citrus. It's may be because their taste is similar to lemons</li></font>

# %%
f, axs = plt.subplots(1, 3, figsize=(40, 40))
for ax, wine in zip(axs, hrv.index[0:3]):
    review = " ".join(text for text in train_data[train_data['variety'] == wine]['review_description'])
    stopwords = set(STOPWORDS)
    # upadating stop words to eliminate name of varieties from review description
    stopwords.update(["drink", "now", "wine", "flavor", "flavors","palate",'Nebbiolo', 
                      'Grüner', 'Veltliner', 'Blend','Champagne', 'Riesling','Pinot','Noir'])

    # Generate a word cloud image
    wcl = WordCloud(stopwords=stopwords, background_color="black").generate(review)

    ax.imshow(wcl, interpolation='bilinear',aspect = 'equal')
    ax.set_title(wine.capitalize())
    ax.grid(False)

plt.show()

# %%
train_data['all_text_combined0'] = train_data['review_title'] +" " + train_data['review_description'] #for training classifier model 2
train_data['all_text_combined1'] = train_data['country'] +" " + train_data['review_title'] +" " + train_data['review_description'] #for training classifier model 3
train_data['all_text_combined2'] = train_data['country'] +" " + train_data['province'] +" " + train_data['review_title'] +" " + train_data['review_description'] #for training classifier model 4
train_data['all_text_combined3'] = train_data['country'] +" " + train_data['province'] +" " + train_data['region_1'] +" " + train_data['review_title'] +" " + train_data['review_description'] #for training classifier model 5
train_data['all_text_combined4'] = train_data['value_for_money'] +" " + train_data['review_title'] +" " + train_data['review_description'] #for training classifier model 6

# %%
test_data['country'] = test_data['country'].fillna('unknown')
test_data['region_1'] = test_data['region_1'].fillna('unknown')
test_data['province'] = test_data['province'].fillna('unknown')
test_data['price'] =  test_data['price'].fillna(test_data['price'].mean())
test_data['quality/price']  =np.array(np.log1p(test_data['points']))/np.array(np.log1p(test_data['price']))
test_data['value_for_money'] = test_data['quality/price'].apply(lambda val : 'High' if val > 1.5 else ('Medium' if val > 1.0 else 'Low'))

# %%
test_data['all_text_combined0'] = test_data['review_title'] +" " + test_data['review_description']#for testing classifier model 2
test_data['all_text_combined1'] = test_data['country'] +" " + test_data['review_title'] +" " + test_data['review_description'] #for testing classifier model 3
test_data['all_text_combined2'] = test_data['country'] +" " + test_data['province'] +" " + test_data['review_title'] +" " + test_data['review_description'] #for testing classifier model 4
test_data['all_text_combined3'] = test_data['country'] +" " + test_data['province'] +" " + test_data['region_1'] +" " + test_data['review_title'] +" " + test_data['review_description'] #for testing classifier model 5
test_data['all_text_combined4'] = test_data['value_for_money'] +" " + test_data['review_title'] +" " + test_data['review_description'] #for training classifier model 6

# %%
train_data.head(5)
# Out:
#        user_name    country  \
# 0            NaN  Australia
# 1  @wawinereport         US
# 2            NaN      Italy
# 3     @vossroger     France
# 4     @vossroger     France
#
#                                         review_title  \
# 0  Andrew Peace 2007 Peace Family Vineyard Chardo...
# 1  North by Northwest 2014 Red (Columbia Valley (...
# 2                  Renato Ratti 2007 Conca  (Barolo)
# 3  Domaine l'Ancienne Cure 2010 L'Abbaye White (B...
# 4  Château du Cèdre 2012 Le Cèdre Vintage Malbec ...
#
#                                   review_description            designation  \
# 0  Classic Chardonnay aromas of apple, pear and h...  Peace Family Vineyard
# 1  This wine is near equal parts Syrah and Merlot...                    NaN
# 2  Barolo Conca opens with inky dark concentratio...                  Conca
# 3  It's impressive what a small addition of Sauvi...               L'Abbaye
# 4  This ripe, sweet wine is rich and full of drie...       Le Cèdre Vintage
#
#    points  price          province                 region_1         region_2  \
# 0      83   10.0   Australia Other  South Eastern Australia              NaN
# 1      89   15.0        Washington     Columbia Valley (WA)  Columbia Valley
# 2      94   80.0          Piedmont                   Barolo              NaN
# 3      87   22.0  Southwest France             Bergerac Sec              NaN
# 4      88   33.0      France Other           Vin de Liqueur              NaN
#
#    ...                     variety quality/price  value_for_money  \
# 0  ...                  Chardonnay      1.847794             High
# 1  ...                   Red Blend      1.622963             High
# 2  ...                    Nebbiolo      1.036279           Medium
# 3  ...  Bordeaux-style White Blend      1.427953           Medium
# 4  ...                      Malbec      1.272881           Medium
#
#   redness_score  whiteness_score  \
# 0             0                2
# 1             1                0
# 2             0                0
# 3             0                0
# 4             0                0
#
#                                   all_text_combined0  \
# 0  Andrew Peace 2007 Peace Family Vineyard Chardo...
# 1  North by Northwest 2014 Red (Columbia Valley (...
# 2  Renato Ratti 2007 Conca  (Barolo) Barolo Conca...
# 3  Domaine l'Ancienne Cure 2010 L'Abbaye White (B...
# 4  Château du Cèdre 2012 Le Cèdre Vintage Malbec ...
#
#                                   all_text_combined1  \
# 0  Australia Andrew Peace 2007 Peace Family Viney...
# 1  US North by Northwest 2014 Red (Columbia Valle...
# 2  Italy Renato Ratti 2007 Conca  (Barolo) Barolo...
# 3  France Domaine l'Ancienne Cure 2010 L'Abbaye W...
# 4  France Château du Cèdre 2012 Le Cèdre Vintage ...
#
#                                   all_text_combined2  \
# 0  Australia Australia Other Andrew Peace 2007 Pe...
# 1  US Washington North by Northwest 2014 Red (Col...
# 2  Italy Piedmont Renato Ratti 2007 Conca  (Barol...
# 3  France Southwest France Domaine l'Ancienne Cur...
# 4  France France Other Château du Cèdre 2012 Le C...
#
#                                   all_text_combined3  \
# 0  Australia Australia Other South Eastern Austra...
# 1  US Washington Columbia Valley (WA) North by No...
# 2  Italy Piedmont Barolo Renato Ratti 2007 Conca ...
# 3  France Southwest France Bergerac Sec Domaine l...
# 4  France France Other Vin de Liqueur Château du ...
#
#                                   all_text_combined4
# 0  High Andrew Peace 2007 Peace Family Vineyard C...
# 1  High North by Northwest 2014 Red (Columbia Val...
# 2  Medium Renato Ratti 2007 Conca  (Barolo) Barol...
# 3  Medium Domaine l'Ancienne Cure 2010 L'Abbaye W...
# 4  Medium Château du Cèdre 2012 Le Cèdre Vintage ...
#
# [5 rows x 21 columns]

# %% [markdown]
# # ![](https://ruder.io/content/images/size/w2000/2018/07/lm_objective.png)
# <br>
#
# <font face ='Times New Roman' font size= 6, color ='blue'>
#
#     <h1>Transfer Learning</h1>
#
# </font>
#
#
# <div style="text-align: justify"> <font size= 5 face ='Times New Roman' color ='black'>Humans can learn tasks and use the skills gained, thus, for some other jobs. The more similar the given assignment is to the prior one, the more comfortable one is in its execution. Conventional ML and deep learning algorithms, until a few years back, could only work in isolation. Every time a new dataset presented itself, the model had to be developed from scratch. Transfer learning is the learning paradigm to overcome the isolation, as mentioned earlier, and utilize the knowledge previously acquired for one task to solve similar ones. Granted Transfer Learning is a fantastic idea to improve deep learning models, but it has its limited uses. It has been working great in the area of Image classification, but when it came to the domain of Natural Language Processing, it couldn't help much.  2018 though, was the exciting moment in the field NLP. As Sebastian Ruder puts it, "NLP's ImageNet moment has arrived," and it sure has.Methods such as ULMFiT, OpenAI GPT, ELMo, and Google AI's BERT have a significant impact on transfer learning in NLP by using language modeling during pre-training. The interesting aspect of the transfer learning methods mentioned above is that they use language models pre-trained on well-formed, massive curated datasets that include full sentences with a clear syntax (such as Wikipedia articles and the 1 billion word benchmark). The given kernel implements the ULMFiT model.</font></div><br>
#
# <font face ='Times New Roman' size=4>
# ***References***
# <br>
#
# https://medium.com/jash-data-sciences/guide-to-text-classification-with-fastai-b161ed07d36d#c04d  <br><br>
#
# https://towardsdatascience.com/transfer-learning-in-nlp-for-tweet-stance-classification-8ab014da8dde  <br><br>
#
# https://ruder.io/nlp-imagenet/  <br><br>
#
# https://www.kaggle.com/heisenbad/sentiment-analysis-with-transfer-learning  <br><br>
#
# https://towardsdatascience.com/finding-good-learning-rate-and-the-one-cycle-policy-7159fe1db5d6  <br><br>
#
# https://towardsdatascience.com/multi-task-learning-in-language-model-for-text-classification-c3acc1fedd89  <br><br>
#
# https://diveki.github.io/projects/wine/sommelier.html  <br><br>
#
# https://arxiv.org/pdf/1801.06146.pdf  <br><br>
#
# https://sgugger.github.io/the-1cycle-policy.html</font>
#
# <br><br>
# <font face ='Times New Roman' size=4> The following flowchart depicts the methodology adopted in this kernel </font><br>
#
# # ![](https://miro.medium.com/max/1400/1*vYrqXT0Z80BdZLVIcNt_Wg.png)

# %% [markdown]
# # Language Model 1

# %%
train_data_lm1 = (TextList.from_df(df=train_data,path='.',cols='review_description').split_by_rand_pct(0.1).label_for_lm().databunch(bs=48))

# %%
train_data_lm1.save('train_data_lm1.pkl')

# %%
train_data_lm1.vocab.itos[:10]
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxfld',
#  'xxmaj',
#  'xxup',
#  'xxrep',
#  'xxwrep',
#  ',']

# %%
train_data_lm1.train_ds[0][0]
# Out:
# Text xxbos xxmaj barolo xxmaj conca opens with inky dark concentration and soothing aromas of black fruit , spice , cola , plum , prune and dried lavender buds . xxmaj the nose presents those ethereal and delicate aromas , but in the mouth , it delivers thicker flavors of chocolate and mocha . xxmaj drink after 2018 .

# %%
train_data_lm1 = load_data('', 'train_data_lm1.pkl', bs=48)

# %%
train_data_lm1.show_batch(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>xxmaj gris and xxmaj muscadelle can do to a xxmaj sauvignon - xxmaj sémillon blend — it turns this into an exotic wine , with spice and lychee flavors . xxbos xxmaj strident aromas of licorice , herbs , berries and mint make it interesting , while the palate is light and fresh , with raspberry and red currant flavors . xxmaj there 's not a lot of heft ,</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>glides for a full 30 seconds . xxbos xxmaj not your standard blackberry - and - oak bomb : there 's zing and snap , and even a whiff of mint to the nose . xxmaj deep and full - flavored , with chocolate , coffee and some earthiness . xxmaj it has the length and supple tannins to qualify it as a winner . xxmaj quite pure and focused</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>prune . xxmaj on the finish , this feels big for its xxunk and tastes mildly bitter . xxbos xxmaj stemmy and fiery on the nose , with light raspberry aromas . xxmaj the palate is lightweight and acidic , while the generic palate shows cherry and plum fruit and heat . xxmaj xxunk on through but does n't register more than the basics . xxbos xxmaj pretty in pink</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>a layer of crisp acidity is surrounded by the generous white and yellow fruits , accented by a touch of toast and spice . xxmaj drink this wine from 2018 . xxbos xxmaj this 80 - 20 blend of xxmaj cabernet xxmaj sauvignon and xxmaj cabernet xxmaj franc shows a bright cherry aroma , with spice , leather and tar notes in the background . xxmaj it shows a soft</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>dark , ripe and compact , this xxmaj cab / xxmaj merlot / xxmaj petit xxmaj verdot blend brings plenty of macho and muscle , layers of black fruits , black smoke , black tea and black olives . xxmaj get the idea ? xxmaj it 's a beautiful effort , and really shines at this price point . xxbos xxmaj this is surprisingly plump and accessible , featuring scents</td>
#     </tr>
#   </tbody>
# </table>

# %%
languageModel1 = language_model_learner(train_data_lm1, arch=AWD_LSTM, pretrained_fnames=fnames, drop_mult=0.3)

# %%
languageModel1.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='1189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       8.33% [99/1189 00:11<02:10 9.1870]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
languageModel1.recorder.plot(skip_end=10)

# %%
languageModel1.fit_one_cycle(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.174467</td>
#       <td>3.066252</td>
#       <td>0.397358</td>
#       <td>02:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.072783</td>
#       <td>2.969343</td>
#       <td>0.407853</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.950190</td>
#       <td>2.904896</td>
#       <td>0.415120</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.852518</td>
#       <td>2.854606</td>
#       <td>0.421496</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.780263</td>
#       <td>2.842340</td>
#       <td>0.423262</td>
#       <td>02:27</td>
#     </tr>
#   </tbody>
# </table>

# %%
languageModel1.save('fine_tuned1')
languageModel1.save_encoder('fine_tuned_enc1')

# %% [markdown]
# # Classifier Model 1

# %%
data_classifier1 = (TextList.from_df(df=train_data,path='.',cols='review_description', vocab=train_data_lm1.vocab)
                     .split_by_rand_pct(0.1)
                     .label_from_df('variety')
                     .add_test(test_data)
                     .databunch(bs=48))

# %%
data_classifier1.save('data_classifier1.pkl')

# %%
data_classifier1 = load_data('','data_classifier1.pkl',bs=48)

# %%
data_classifier1.show_batch(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj this very fine xxmaj cabernet wants a little time in the cellar . xxmaj right now , it 's tight in tannins , with some acidic bitterness in the finish . xxmaj the flavors are of black currants and smoky new oak . xxmaj the xxmaj morisoli xxmaj vineyard has been home to very good , ageable bottlings from the likes of xxmaj sequoia xxmaj grove and xxmaj</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj this blend is near - equal parts xxmaj merlot , xxmaj cabernet xxmaj franc and xxmaj cabernet xxmaj sauvignon along with a healthy dollop of xxmaj petit xxmaj verdot ( 18 % ) . xxmaj it shows a mix of fruit and savory elements , with notes of potting soil , green coffee bean , mocha , fresh herbs , licorice , generous barrel spices and red and</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos a hint of smoke and a touch of earth precede the fresh lemon notes of the nose . xxmaj the dry palate , with its vivid impression of very pure , bright and incisive lemon freshness , still seems tightly wound . xxmaj there is something brooding and alive about this — it can be felt below the surface , xxunk but promising . xxmaj this has barely started</td>
#       <td>Riesling</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj this eccentric xxmaj chard marches to its own beat . xxmaj it 's drier and more acidic than most , and the flavors offer a mélange of peaches , oranges , tropical fruits , xxmaj meyer lemons , cashews and white flowers . xxmaj yet it 's delicious and compelling . xxmaj made with full - throttle techniques that include partial barrel fermentation , malolactic fermentation and battonage</td>
#       <td>Chardonnay</td>
#     </tr>
#     <tr>
#       <td>xxbos a clean - cut top note of citrus hovers above the otherwise still - closed nose . xxmaj the palate comes in with a concentrated richness that is as much sustained by residual sweetness as it is by sheer force of fruit : candied lemon and orange , juicy pear , ripe mirabelle and yellow peach . xxmaj there also is a zesty spicy pithiness on the midpalate that</td>
#       <td>Gewürztraminer</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj the blend is classic xxmaj xxunk % xxmaj cabernet xxmaj sauvignon , 7 % xxmaj merlot , 5 % xxmaj cabernet xxmaj franc and 3 % xxmaj malbec . xxmaj it 's got grip and a sensuous mix of wild herb , black olive and mountain berry . xxmaj there is plenty of acid to support it , and winemaker j - f xxmaj pellet has been pulling</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj this is by far the most expensive of xxmaj duckhorn 's new releases , but it 's not the best to drink now . xxmaj based on xxmaj cabernet xxmaj sauvignon , it 's easy to imagine the winemaker xxunk out the most tannic and concentrated lots , but what you get is , simply , a very tannic wine . xxmaj there 's a gigantic core of</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos a touch of flint on fleshy peach is followed by juicy citrus and ripe pear bedded in nettle and watercress . xxmaj together they present an immensely enticing nose , hinting at whole oceans of luscious fruit beneath the surface . xxmaj the palate then xxunk all the varietal spice : white pepper , arugula and chervil , illuminated by bright , zesty citrus to finish in a xxunk</td>
#       <td>Grüner Veltliner</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj this is an aromatic , smoky , herbal and ultimately captivating xxmaj syrah . xxmaj dense , smoky , tarry and herbal , it is a serious effort from a winery that specializes in the grape . xxmaj the fruit is a juicy mix of wild berries , cassis and black cherry , with substantial tannins that add herbal , green tea flavors . xxmaj give it time</td>
#       <td>Syrah</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj this wine comes from a recently planted area of valley , high on a ridge top . a blend of 56 % xxmaj cabernet xxmaj sauvignon , 32 % xxmaj merlot , 6 % xxmaj cabernet xxmaj franc and 6 % xxmaj malbec , the aromas boast high - toned notes of mineral , herb , cherry , licorice and dark fruit . xxmaj the cranberry and cherry</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel1 = text_classifier_learner(data_classifier1, arch=AWD_LSTM, drop_mult=0.5)
classifierModel1.load_encoder('fine_tuned_enc1')
classifierModel1.freeze()
# Out:
# Downloading https://s3.amazonaws.com/fast-ai-modelzoo/wt103-fwd

# %%
classifierModel1.summary()
# Out:
# SequentialRNN
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# RNNDropout           [40, 400]            0          False
# ______________________________________________________________________
# RNNDropout           [40, 1152]           0          False
# ______________________________________________________________________
# RNNDropout           [40, 1152]           0          False
# ______________________________________________________________________
# BatchNorm1d          [1200]               2,400      True
# ______________________________________________________________________
# Dropout              [1200]               0          False
# ______________________________________________________________________
# Linear               [50]                 60,050     True
# ______________________________________________________________________
# ReLU                 [50]                 0          False
# ______________________________________________________________________
# BatchNorm1d          [50]                 100        True
# ______________________________________________________________________
# Dropout              [50]                 0          False
# ______________________________________________________________________
# Linear               [28]                 1,428      True
# ______________________________________________________________________
#
# Total params: 63,978
# Total trainable params: 63,978
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied
#     RNNTrainer

# %%
classifierModel1.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='95' class='' max='1549' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.13% [95/1549 00:12<03:04 8.7984]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
classifierModel1.recorder.plot()

# %%
classifierModel1.fit_one_cycle(1, 2e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.771646</td>
#       <td>1.435527</td>
#       <td>0.553781</td>
#       <td>02:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
for i in range(2,5):
    classifierModel1.freeze_to(-i)
    classifierModel1.fit_one_cycle(1,slice((1*10**-i)/(2.6**4),1*10**-i))
    print ('')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.292553</td>
#       <td>1.091827</td>
#       <td>0.651059</td>
#       <td>02:19</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.177927</td>
#       <td>0.989448</td>
#       <td>0.682154</td>
#       <td>02:12</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.127160</td>
#       <td>0.979673</td>
#       <td>0.690744</td>
#       <td>02:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel1.recorder.plot_losses() ##still have to figure out why validation losses are not getting plotted

# %%
classifierModel1.unfreeze()
classifierModel1.fit_one_cycle(2, slice(1e-5/(2.6**4),1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.103715</td>
#       <td>0.960835</td>
#       <td>0.696673</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.089851</td>
#       <td>0.947139</td>
#       <td>0.699577</td>
#       <td>02:30</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel1.fit_one_cycle(5, slice(1e-5,1e-3))
print ('')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.063755</td>
#       <td>0.934276</td>
#       <td>0.704053</td>
#       <td>02:35</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.026171</td>
#       <td>0.890830</td>
#       <td>0.719540</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.920169</td>
#       <td>0.866801</td>
#       <td>0.722081</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.948689</td>
#       <td>0.853239</td>
#       <td>0.728736</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.905939</td>
#       <td>0.851496</td>
#       <td>0.731881</td>
#       <td>02:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel1.save('classifierModel1')

# %%
classifierModel1.show_results(rows = 100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj this is a xxmaj pinot xxmaj noir of considerable force . xxmaj your first impression is of xxunk power , with masses of fruit punching through an overlay of tannin and oak . xxmaj then the flavors xxunk out , suggesting cherries , cola , currants and spices that are rich and complex through the long finish . xxmaj for all its richness , the wine retains an</td>
#       <td>Pinot Noir</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos a stupendous xxmaj pinot xxmaj noir , showing how beautifully this vineyard performs in the remote xxmaj sonoma xxmaj coast above xxmaj fort xxmaj ross . xxmaj williams xxmaj selyem 's last few vintages of xxmaj precious xxmaj mountain have been extraordinary , but this 2009 tops them all . xxmaj the wine is as light as a feather in the mouth , modest in alcohol and delicately feminine</td>
#       <td>Pinot Noir</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos a fine follow - up to xxmaj xxunk 's inaugural 2004 xxmaj clifton xxmaj hill , this again delivers ripe , concentrated flavors of plum and berry , lifted with citrus and finishing with a hint of mint . xxmaj despite the high ( 15.3 % ) alcohol , it is clean and bracing , with natural acids and very little heat in the finish . xxmaj as young</td>
#       <td>Syrah</td>
#       <td>Syrah</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj the grapes for this immense , rich blueberry jammy xxmaj syrah come from xxup nfl 's xxmaj john xxmaj xxunk 's ranch . xxmaj it 's as big and loud as he can be , with not quite enough fruit or acid to overcome the alcohol , which even gets in the way of the nose . xxmaj with a small percentage of xxmaj grenache blended in and</td>
#       <td>Syrah</td>
#       <td>Syrah</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj the production of xxmaj long xxmaj haul has doubled in 2010 , and vineyard sources have changed , though most remain on xxmaj red xxmaj mountain despite the xxmaj columbia xxmaj valley appellation . xxmaj the xxmaj bordeaux - style blend is 61 % xxmaj merlot , 16 % xxmaj cabernet xxmaj sauvignon , 12 % xxmaj cabernet xxmaj franc , 9 % xxmaj malbec and 2 %</td>
#       <td>Bordeaux-style Red Blend</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj the statewide appellation reflects the fact that the grapes were sourced from xxmaj napa xxmaj carneros , xxmaj sonoma , xxmaj monterey and xxmaj santa xxmaj barbara . xxmaj that makes it a master of the art of blending . xxmaj meanwhile , the great 2012 vintage , which was successful throughout the state , is responsible for the wine 's balance . xxmaj it 's rich in</td>
#       <td>Chardonnay</td>
#       <td>Chardonnay</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj this inaugural release from former xxup nfl xxunk xxmaj dan xxmaj xxunk and xxmaj xxunk xxmaj xxunk is a blend of 86 % xxmaj discovery xxmaj cabernet xxmaj sauvignon , 9 % xxmaj klipsun xxmaj merlot and 5 % xxmaj champoux xxmaj cabernet xxmaj franc . xxmaj it 's aromatically brooding at xxunk , with notes of dark coffee , dusty earth and cherry . xxmaj the soft</td>
#       <td>Cabernet Sauvignon</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos a terrific example of xxmaj corbières terroir at an unbeatable price . xxmaj the wine , a traditional xxmaj rhône - style blend of xxmaj syrah , xxmaj grenache and xxmaj carignan , is so loaded with aromas and flavors of the surrounding garrigue you might think that they xxunk in a bouquet garni during maturation . xxmaj sage , rosemary , menthol , thyme and bay leaves all</td>
#       <td>Rhône-style Red Blend</td>
#       <td>Rhône-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj xxunk 's xxmaj bordeaux - style blend , made with 48 % xxmaj cabernet xxmaj sauvignon , 45 % xxmaj merlot , 4 % xxmaj petit xxmaj verdot , 2 % xxmaj malbec and 1 % xxmaj cabernet xxmaj franc , is a complex and layered wine , with waves of black fruit and earthy spice that dance endlessly on the nose and mouth . xxmaj heady notes</td>
#       <td>Bordeaux-style Red Blend</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj from xxmaj robert xxmaj mondavi and xxmaj xxunk xxmaj xxunk , a xxmaj chilean producer ( xxmaj xxunk ) , this wine is a blend of 84 % xxmaj cabernet xxmaj sauvignon and 16 % xxmaj carmenère . xxmaj the color is inky dark , and it smells young and intense , almost fiery — there 's a suggestion of charcoal and embers . xxmaj massive fruit explodes</td>
#       <td>Bordeaux-style Red Blend</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos a blend of 68 % xxmaj shiraz , 18 % xxmaj grenache , 10 % xxmaj cinsault and 4 % xxmaj tinta xxmaj barocca , this is one of the finest reds coming out of xxmaj south xxmaj africa today . xxmaj it is powerful and concentrated , yet elegant and refined , with notes of lush red cherry , raspberry and plum that are complemented by notes of</td>
#       <td>Red Blend</td>
#       <td>Rhône-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj hat xxmaj trick is the best of the best of xxmaj morgan 's estate vineyard , which is in the xxunk northwestern part of the xxmaj highlands . xxmaj acidity stars , giving the wine a brilliant crispness that 's so clean and fine . xxmaj barrel fermented in one - third new xxmaj french oak , the wine is incredibly rich and leesy . xxmaj the terroir</td>
#       <td>Chardonnay</td>
#       <td>Chardonnay</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj this is 100 % new oak ( primarily xxmaj taransaud , 32 months ) , and it 's a marvelous example of the grape , the vineyard and the strengths of xxmaj washington fruit . xxmaj the xxmaj shafer xxmaj hillside xxmaj select is the inspiration for the extended barrel aging and the focus on round , sweet tannins . xxmaj this is a tight wine , with</td>
#       <td>Cabernet Sauvignon</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos a blend of 57 % xxmaj cabernet xxmaj sauvignon , 14 % xxmaj merlot , 13 % xxmaj malbec , 11 % xxmaj cabernet xxmaj franc and 5 % xxmaj petit xxmaj verdot , this stunning , well - balanced wine will reward patience . xxmaj dark and dense , it 's a powerful selection that boasts serious fruit concentration and a full , firm structure , with mouthcoating</td>
#       <td>Bordeaux-style Red Blend</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj at 98 years of age , the vineyard certainly qualifies as old vine , which is n't the case with all wines so labeled . xxmaj who really knows what varieties actually constitute these ancient vineyards , but this wine is certainly rich in xxmaj zinfandel character . xxmaj the wild raspberry and cherry fruits have a briary edge , suggesting the tartness of xxmaj dr. xxmaj pepper</td>
#       <td>Zinfandel</td>
#       <td>Zinfandel</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj this is a unique xxmaj pinot xxmaj noir , different from almost everything else out there . xxmaj sourced from a vineyard in the xxmaj petaluma xxmaj gap region ( perhaps a future xxup ava ) , it 's bone dry , moderate in alcohol , and tannic . xxmaj it has lighter , leaner flavors than most xxmaj pinots , with the fruit accompanied by herbs ,</td>
#       <td>Pinot Noir</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj if you must open this now , let it breath for a while because it ’s dumb , as they say , on opening . xxmaj airing and swirling reveal more earthy things than fruit . xxmaj there ’s a hint of truffles , of bark , and you almost have to close your eyes to imagine the blackberries and cherries buried deep down inside , but they</td>
#       <td>Pinot Noir</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <t

# %%
train_loss1,train_accuracy1 = classifierModel1.validate(classifierModel1.data.train_dl)

# %%
valid_loss1,valid_accuracy1 = classifierModel1.validate(classifierModel1.data.train_dl)

# %%
print("Training Accuracy from model 1 is {0}".format(train_accuracy1*100))
print('')
print("Validation Accuracy from model 1 is {0}".format(valid_accuracy1*100))
# Out:
# Training Accuracy from model 1 is 76.70001983642578
#
# Validation Accuracy from model 1 is 76.66908264160156

# %%
def build_submission_file(model,predictions,fileName):
    
    labels = []
    final_data =pd.read_csv('/kaggle/input/wine-dataset/test.csv')
    
    for i in predictions[0]:
        labels.append(model.data.classes[np.argmax(i)])
    
    submission_final = pd.concat([final_data,pd.DataFrame(labels,columns = ['variety'])],
                     axis = 1)
    submission_final.to_csv(fileName,index = False, header=True)
    return submission_final

# %%
preds1 = classifierModel1.get_preds(DatasetType.Test)

# %%
build_submission_file(classifierModel1,preds1,'submission1.csv')
# Out:
#               user_name    country  \
# 0           @paulgwine          US
# 1           @wineschach  Argentina
# 2               @vboone         US
# 3           @wineschach  Argentina
# 4          @kerinokeefe      Italy
# ...                 ...        ...
# 20660  @gordone_cellars         US
# 20661         @laurbuzz     France
# 20662     @mattkettmann         US
# 20663       @wineschach      Spain
# 20664               NaN         US
#
#                                             review_title  \
# 0      Boedecker Cellars 2011 Athena Pinot Noir (Will...
# 1      Mendoza Vineyards 2012 Gran Reserva by Richard...
# 2                    Prime 2013 Chardonnay (Coombsville)
# 3      Bodega Cuarto Dominio 2012 Chento Vineyard Sel...
# 4               SassodiSole 2012  Brunello di Montalcino
# ...                                                  ...
# 20660  Yorkville Cellars 2013 Rennie Vineyard Caberne...
# 20661  Château Ribaute 2015 Senhal d'Aric Rosé (Corbi...
# 20662  Daou 2014 Reserve Cabernet Sauvignon (Paso Rob...
# 20663  Peñascal 2011 Tempranillo Rosé (Vino de la Tie...
# 20664  Langtry 2005 Tephra Ridge Vineyard Cabernet Sa...
#
#                                       review_description  \
# 0      Nicely differentiated from the companion Stewa...
# 1      Charred, smoky, herbal aromas of blackberry tr...
# 2      Slightly sour and funky in earth, this is a re...
# 3      This concentrated, midnight-black Malbec deliv...
# 4      Earthy aromas suggesting grilled porcini, leat...
# ...                                                  ...
# 20660  Clearly focused and fruit-driven, this wine ha...
# 20661  Herbal tones of bay and rosemary are upfront o...
# 20662  Mocha cream, pencil shaving and dried herb aro...
# 20663  Loud citrus and berry aromas precede an overlo...
# 20664  With very ripe fruit and firm tannins, this mo...
#
#                           designation  points  price              province  \
# 0                              Athena      88   35.0                Oregon
# 1      Gran Reserva by Richard Bonvin      90   60.0      Mendoza Province
# 2                                 NaN      87   38.0            California
# 3           Chento Vineyard Selection      91   20.0      Mendoza Province
# 4                                 NaN      90   49.0               Tuscany
# ...                               ...     ...    ...                   ...
# 20660                 Rennie Vineyard      91   34.0            California
# 20661                   Senhal d'Aric      84   20.0  Languedoc-Roussillon
# 20662                         Reserve      94   85.0            California
# 20663                     Tempranillo      80    9.0        Northern Spain
# 20664           Tephra Ridge Vineyard      87   40.0            California
#
#                                    region_1           region_2  \
# 0                         Willamette Valley  Willamette Valley
# 1                                   Mendoza                NaN
# 2                               Coombsville               Napa
# 3                                   Mendoza                NaN
# 4                    Brunello di Montalcino                NaN
# ...                                     ...                ...
# 20660                   Yorkville Highlands        North Coast
# 20661                             Corbières                NaN
# 20662                           Paso Robles      Central Coast
# 20663  Vino de la Tierra de Castilla y León                NaN
# 20664                           Lake County                NaN
#
#                       winery             variety
# 0          Boedecker Cellars          Pinot Noir
# 1          Mendoza Vineyards              Malbec
# 2                      Prime          Chardonnay
# 3      Bodega Cuarto Dominio              Malbec
# 4                SassodiSole          Sangiovese
# ...                      ...                 ...
# 20660      Yorkville Cellars      Cabernet Franc
# 20661        Château Ribaute                Rosé
# 20662                   Daou  Cabernet Sauvignon
# 20663               Peñascal         Tempranillo
# 20664                Langtry  Cabernet Sauvignon
#
# [20665 rows x 12 columns]

# %% [markdown]
# # Language Model 2

# %%
train_data_lm2 = (TextList.from_df(df=train_data,path='.',cols='all_text_combined0').split_by_rand_pct(0.1).label_for_lm().databunch(bs=48))

# %%
train_data_lm2.save('train_data_lm2.pkl')

# %%
train_data_lm2.vocab.itos[:10]
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxfld',
#  'xxmaj',
#  'xxup',
#  'xxrep',
#  'xxwrep',
#  ',']

# %%
train_data_lm2.train_ds[0][0]
# Out:
# Text xxbos xxmaj andrew xxmaj peace 2007 xxmaj peace xxmaj family xxmaj vineyard xxmaj chardonnay ( xxmaj south xxmaj eastern xxmaj australia ) xxmaj classic xxmaj chardonnay aromas of apple , pear and hay lead into a palate marked by decent intensity but also a bit of sweetness . xxmaj orange and candy notes run through the rather short finish .

# %%
train_data_lm2 = load_data('', 'train_data_lm2.pkl', bs=48)

# %%
train_data_lm2.show_batch(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>xxmaj columbia xxmaj valley ( xxup wa ) ) xxmaj this wine is near equal parts xxmaj syrah and xxmaj merlot with the balance xxmaj cabernet xxmaj sauvignon . xxmaj aromas of blue fruit , vanilla , cherry and herb lead to full - bodied pit - fruit flavors that bring a sense of deliciousness that is hard to resist . xxbos xxmaj renato xxmaj ratti 2007 xxmaj conca (</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>xxmaj it has weight and ripe blackberry fruit , plus a fine line of acidity . xxmaj wait for two years , although it is drinkable now . xxbos podernuovo a xxmaj palazzone 2011 xxmaj therra xxmaj red ( xxmaj toscana ) xxmaj montepulciano , xxmaj sangiovese , xxmaj merlot and xxmaj cabernet xxmaj sauvignon grapes team up to produce this firmly structured but accessible red . xxmaj the palate</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>( for xxmaj oregon xxmaj pinot xxmaj noir ) where it shines . xxmaj fruity and forward , there 's plenty to like in the mix of orange flesh and rind , and strawberry and cherry hard candy . xxmaj the fruit is backed with ample tannin , and a warm touch of mocha and toast fills in the finish . xxbos xxmaj purple xxmaj star 2009 xxmaj cabernet xxmaj</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>palate that has sweet flavors but little residual sugar . xxmaj medium , pear - accented finish . xxmaj drink now . xxbos xxmaj poggio xxmaj nardone 2012 xxmaj brunello di xxmaj montalcino xxmaj dark - skinned berry , underbrush and leather aromas lead the nose . xxmaj the palate is firm , offering plum , toast , mocha and tobacco flavors , while assertive tannins leave a taut finish</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>verdot and xxmaj merlot , from the xxmaj figgins xxmaj vineyard , with gorgeous aromas of flowers , spices and black fruits . xxmaj seamless and long , complex and forceful without being overpowering , it can stand alongside top tier xxmaj bordeaux costing four or five times as much . xxbos xxmaj quinta da xxmaj alorna 2016 xxmaj vinho xxmaj branco xxmaj white ( xxmaj tejo ) xxmaj this</td>
#     </tr>
#   </tbody>
# </table>

# %%
languageModel2 = language_model_learner(train_data_lm2, arch=AWD_LSTM, pretrained_fnames=fnames, drop_mult=0.3)

# %%
languageModel2.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='1543' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.42% [99/1543 00:13<03:16 8.6554]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
languageModel2.recorder.plot(skip_end=10)

# %%
languageModel2.fit_one_cycle(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.835753</td>
#       <td>2.720673</td>
#       <td>0.467246</td>
#       <td>03:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.717209</td>
#       <td>2.606338</td>
#       <td>0.480632</td>
#       <td>03:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.589158</td>
#       <td>2.527345</td>
#       <td>0.489606</td>
#       <td>03:37</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.463874</td>
#       <td>2.466942</td>
#       <td>0.497688</td>
#       <td>03:36</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.379976</td>
#       <td>2.452364</td>
#       <td>0.499924</td>
#       <td>03:38</td>
#     </tr>
#   </tbody>
# </table>

# %%
#languageModel2.save('fine_tuned2')
languageModel2.save_encoder('fine_tuned_enc2')

# %% [markdown]
# # Classifier Model 2

# %%
data_classifier2 = (TextList.from_df(df=train_data,path='.',cols='all_text_combined0', vocab=train_data_lm2.vocab)
                    .split_by_rand_pct(0.1)
                    .label_from_df('variety')
                    .add_test(test_data)
                    .databunch(bs=48))

# %%
data_classifier2.save('data_classifier2.pkl')

# %%
data_classifier2 = load_data('','data_classifier2.pkl',bs=48)

# %%
data_classifier2.show_batch(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj saggi 2007 xxmaj red ( xxmaj columbia xxmaj valley ( xxup wa ) ) xxmaj dark , dusty , strongly scented with barrel toast , coffee grounds and incense , this is the most substantial and complete version to date . xxmaj balancing cherry and plum fruit against the pretty barrel - infused tannins , it glides gracefully across the palate into a seamless finish . xxmaj saggi</td>
#       <td>Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj lemelson 2006 xxmaj jerome xxmaj reserve xxmaj pinot xxmaj noir ( xxmaj willamette xxmaj valley ) xxmaj this complex wine lists no fewer than eight different clones in the blend , harvested at an average of just xxunk tons / acre . xxmaj the winery suggests that it is their most ageworthy xxmaj pinot xxmaj noir , and the structure of this young wine would support that xxunk</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj yao xxmaj ming 2009 xxmaj family xxmaj reserve xxmaj cabernet xxmaj sauvignon ( xxmaj napa xxmaj valley ) xxmaj the former xxunk star 's initial release immediately xxunk itself among the elite xxmaj cabernets of xxmaj napa xxmaj valley . xxmaj made from mountain vineyards on xxmaj atlas xxmaj peak and benches in the xxmaj rutherford appellation , it combines intensity with elegance . xxmaj bursts with upfront</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos 21 xxmaj grams 2011 xxmaj red ( xxmaj washington ) xxmaj this wine is mostly xxmaj cabernet xxmaj sauvignon ( 85 % ) along with 9 % xxmaj petit xxmaj verdot and 6 % xxmaj malbec , with most of the fruit coming from top sites of xxmaj cold xxmaj creek xxmaj vineyard and xxmaj stone xxmaj tree vineyards . xxmaj tightly wound up right now , it offers</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj trefethen 2008 halo xxmaj cabernet xxmaj sauvignon ( xxmaj oak xxmaj knoll xxmaj district ) xxmaj trefethen has been on a roll the last few years , producing some of xxmaj napa 's most spectacular xxmaj cabernets . xxmaj this bottling , which contains minor quantities of xxmaj petit xxmaj verdot and xxmaj merlot , spent 28 months in new xxmaj french oak barrels . xxmaj the fruit</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel2 = text_classifier_learner(data_classifier2, arch=AWD_LSTM, drop_mult=0.5)
classifierModel2.load_encoder('fine_tuned_enc2')
classifierModel2.freeze()

# %%
classifierModel2.summary()
# Out:
# SequentialRNN
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# RNNDropout           [50, 400]            0          False
# ______________________________________________________________________
# RNNDropout           [50, 1152]           0          False
# ______________________________________________________________________
# RNNDropout           [50, 1152]           0          False
# ______________________________________________________________________
# BatchNorm1d          [1200]               2,400      True
# ______________________________________________________________________
# Dropout              [1200]               0          False
# ______________________________________________________________________
# Linear               [50]                 60,050     True
# ______________________________________________________________________
# ReLU                 [50]                 0          False
# ______________________________________________________________________
# BatchNorm1d          [50]                 100        True
# ______________________________________________________________________
# Dropout              [50]                 0          False
# ______________________________________________________________________
# Linear               [28]                 1,428      True
# ______________________________________________________________________
#
# Total params: 63,978
# Total trainable params: 63,978
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied
#     RNNTrainer

# %%
classifierModel2.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='95' class='' max='1549' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.13% [95/1549 00:14<03:43 8.4050]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
classifierModel2.recorder.plot()

# %%
classifierModel2.fit_one_cycle(1, 2e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.829014</td>
#       <td>0.375494</td>
#       <td>0.879371</td>
#       <td>02:49</td>
#     </tr>
#   </tbody>
# </table>

# %%
for i in range(2,5):
    classifierModel2.freeze_to(-i)
    classifierModel2.fit_one_cycle(1,slice((1*10**-i)/(2.6**4),1*10**-i))
    print ('')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.175030</td>
#       <td>0.087177</td>
#       <td>0.970599</td>
#       <td>02:48</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.104862</td>
#       <td>0.073780</td>
#       <td>0.973866</td>
#       <td>03:01</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.100204</td>
#       <td>0.071395</td>
#       <td>0.973987</td>
#       <td>02:59</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel2.recorder.plot_losses()

# %%
train_loss2,train_accuracy2 = classifierModel2.validate(classifierModel2.data.train_dl)

# %%
valid_loss2,valid_accuracy2 = classifierModel2.validate(classifierModel2.data.valid_dl)

# %%
print("Training Accuracy from model 2 is {0}".format(train_accuracy2*100))
print('')
print("Validation Accuracy from model 2 is {0}".format(valid_accuracy2*100))
# Out:
# Training Accuracy from model 2 is 97.7566146850586
#
# Validation Accuracy from model 2 is 97.39866638183594

# %%
classifierModel2.show_results(rows=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj meander 2006 xxmaj morisoli xxmaj vineyard xxmaj cabernet xxmaj sauvignon ( xxmaj rutherford ) xxmaj this very fine xxmaj cabernet wants a little time in the cellar . xxmaj right now , it 's tight in tannins , with some acidic bitterness in the finish . xxmaj the flavors are of black currants and smoky new oak . xxmaj the xxmaj morisoli xxmaj vineyard has been home to</td>
#       <td>Cabernet Sauvignon</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj williams xxmaj selyem 2010 30th xxmaj anniversary xxmaj cuvée xxmaj estate xxmaj vineyard xxmaj pinot xxmaj noir ( xxmaj russian xxmaj river xxmaj valley ) xxmaj this is a xxmaj pinot xxmaj noir of considerable force . xxmaj your first impression is of xxunk power , with masses of fruit punching through an overlay of tannin and oak . xxmaj then the flavors fantail out , suggesting cherries</td>
#       <td>Pinot Noir</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj schramsberg 2004 xxmaj reserve xxmaj sparkling ( xxmaj napa - xxmaj mendocino - xxmaj sonoma - xxmaj marin ) xxmaj the opulence of this sparkling wine has to be tasted to be believed . xxmaj it 's far softer and silkier than the winery 's companion new release , the 2005 xxup j. xxmaj schram , but then the blend is the complete opposite . xxmaj this one</td>
#       <td>Sparkling Blend</td>
#       <td>Sparkling Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj failla 2010 xxmaj hirsch xxmaj vineyard xxmaj pinot xxmaj noir ( xxmaj sonoma xxmaj coast ) xxmaj this shows the trifecta of winemaker xxmaj ehren xxmaj jordan 's deft hand , the fabulous xxmaj hirsch xxmaj vineyard and the wonderful 2010 vintage . xxmaj even if you knew nothing of the wine 's pedigree , you 'd be dazzled by its sheer richness of raspberry , cherry ,</td>
#       <td>Pinot Noir</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj paul xxmaj cluver 2016 xxmaj cape xxmaj winemakers xxmaj guild xxmaj the xxmaj wagon xxmaj trail xxmaj chardonnay ( xxmaj elgin ) xxmaj winemaker : xxmaj andries xxmaj burger . xxmaj always a stunner , the 2016 xxmaj wagon xxmaj trail delivers impeccable balance , freshness and minerality that can easily translate in the wine being mistaken for one from another iconic xxmaj old xxmaj world xxmaj chardonnay</td>
#       <td>Chardonnay</td>
#       <td>Chardonnay</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj newton xxmaj johnson 2016 xxmaj cape xxmaj winemakers xxmaj guild xxmaj xxunk xxmaj pinot xxmaj noir xxmaj winemaker : xxmaj gordon xxmaj newton xxmaj johnson . xxmaj this is such a pretty and elegant xxmaj pinot , certainly not what most would expect from a " xxmaj new xxmaj world " wine region . xxmaj it expresses the masterful balance that xxmaj south xxmaj african xxmaj pinot can</td>
#       <td>Pinot Noir</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj joseph xxmaj phelps 2009 xxmaj insignia xxmaj estate xxmaj grown xxmaj red ( xxmaj napa xxmaj valley ) xxmaj this wine continues a long - standing tradition , showing a mastery of the art of blending . xxmaj it 's made using grapes that are sourced from at least six vineyards scattered from xxmaj yountville to xxmaj st. xxmaj helena . xxmaj right out of the bottle ,</td>
#       <td>Red Blend</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj domaine xxmaj schoffit 2012 xxmaj clos xxmaj saint - xxmaj théobald xxmaj rangen xxmaj grand xxmaj cru xxmaj sélection de xxmaj grains xxmaj nobles xxmaj pinot xxmaj gris ( xxmaj alsace ) xxmaj the musky touch of botrytized fruit appears immediately , adding even more allure to the golden color . xxmaj an explosion of golden apricot and luscious peach provide mouthfilling sweetness on the palate . xxmaj</td>
#       <td>Pinot Gris</td>
#       <td>Pinot Gris</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj domaine xxmaj zind - xxmaj humbrecht 2013 xxmaj clos xxmaj saint xxmaj urbain xxmaj rangen de xxmaj thann xxmaj grand xxmaj cru xxmaj riesling ( xxmaj alsace ) xxmaj subtle smoke hovers above earthy notes and the nose only holds the faintest suggestion of citrus . xxmaj the palate comes forth with a vivid , leafy purity that suggests herbs , freshly turned earth and pure , lifted</td>
#       <td>Riesling</td>
#       <td>Riesling</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj wood xxmaj family xxmaj vineyards 2007 xxmaj madden xxmaj ranch xxmaj syrah ( xxmaj livermore xxmaj valley ) xxmaj the grapes for this immense , rich blueberry jammy xxmaj syrah come from xxup xxunk 's xxmaj john xxmaj madden 's ranch . xxmaj it 's as big and loud as he can be , with not quite enough fruit or acid to overcome the alcohol , which even</td>
#       <td>Syrah</td>
#       <td>Syrah</td>
#     </tr>
#   </tbody>
# </table>

# %%
preds2 = classifierModel2.get_preds(DatasetType.Test)

# %%
classifierModel2.save('classifierModel2')

# %%
build_submission_file(classifierModel2,preds2,'submission2.csv')
# Out:
#               user_name    country  \
# 0           @paulgwine          US
# 1           @wineschach  Argentina
# 2               @vboone         US
# 3           @wineschach  Argentina
# 4          @kerinokeefe      Italy
# ...                 ...        ...
# 20660  @gordone_cellars         US
# 20661         @laurbuzz     France
# 20662     @mattkettmann         US
# 20663       @wineschach      Spain
# 20664               NaN         US
#
#                                             review_title  \
# 0      Boedecker Cellars 2011 Athena Pinot Noir (Will...
# 1      Mendoza Vineyards 2012 Gran Reserva by Richard...
# 2                    Prime 2013 Chardonnay (Coombsville)
# 3      Bodega Cuarto Dominio 2012 Chento Vineyard Sel...
# 4               SassodiSole 2012  Brunello di Montalcino
# ...                                                  ...
# 20660  Yorkville Cellars 2013 Rennie Vineyard Caberne...
# 20661  Château Ribaute 2015 Senhal d'Aric Rosé (Corbi...
# 20662  Daou 2014 Reserve Cabernet Sauvignon (Paso Rob...
# 20663  Peñascal 2011 Tempranillo Rosé (Vino de la Tie...
# 20664  Langtry 2005 Tephra Ridge Vineyard Cabernet Sa...
#
#                                       review_description  \
# 0      Nicely differentiated from the companion Stewa...
# 1      Charred, smoky, herbal aromas of blackberry tr...
# 2      Slightly sour and funky in earth, this is a re...
# 3      This concentrated, midnight-black Malbec deliv...
# 4      Earthy aromas suggesting grilled porcini, leat...
# ...                                                  ...
# 20660  Clearly focused and fruit-driven, this wine ha...
# 20661  Herbal tones of bay and rosemary are upfront o...
# 20662  Mocha cream, pencil shaving and dried herb aro...
# 20663  Loud citrus and berry aromas precede an overlo...
# 20664  With very ripe fruit and firm tannins, this mo...
#
#                           designation  points  price              province  \
# 0                              Athena      88   35.0                Oregon
# 1      Gran Reserva by Richard Bonvin      90   60.0      Mendoza Province
# 2                                 NaN      87   38.0            California
# 3           Chento Vineyard Selection      91   20.0      Mendoza Province
# 4                                 NaN      90   49.0               Tuscany
# ...                               ...     ...    ...                   ...
# 20660                 Rennie Vineyard      91   34.0            California
# 20661                   Senhal d'Aric      84   20.0  Languedoc-Roussillon
# 20662                         Reserve      94   85.0            California
# 20663                     Tempranillo      80    9.0        Northern Spain
# 20664           Tephra Ridge Vineyard      87   40.0            California
#
#                                    region_1           region_2  \
# 0                         Willamette Valley  Willamette Valley
# 1                                   Mendoza                NaN
# 2                               Coombsville               Napa
# 3                                   Mendoza                NaN
# 4                    Brunello di Montalcino                NaN
# ...                                     ...                ...
# 20660                   Yorkville Highlands        North Coast
# 20661                             Corbières                NaN
# 20662                           Paso Robles      Central Coast
# 20663  Vino de la Tierra de Castilla y León                NaN
# 20664                           Lake County                NaN
#
#                       winery             variety
# 0          Boedecker Cellars          Pinot Noir
# 1          Mendoza Vineyards              Malbec
# 2                      Prime          Chardonnay
# 3      Bodega Cuarto Dominio              Malbec
# 4                SassodiSole          Sangiovese
# ...                      ...                 ...
# 20660      Yorkville Cellars      Cabernet Franc
# 20661        Château Ribaute                Rosé
# 20662                   Daou  Cabernet Sauvignon
# 20663               Peñascal                Rosé
# 20664                Langtry  Cabernet Sauvignon
#
# [20665 rows x 12 columns]

# %%
classifierModel2.unfreeze()
classifierModel2.fit_one_cycle(1, slice(1e-5/(2.6**4),1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.120754</td>
#       <td>0.067793</td>
#       <td>0.975681</td>
#       <td>03:00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Language Model 3

# %%
train_data_lm3 = (TextList.from_df(df=train_data,path='.',cols='all_text_combined1').split_by_rand_pct(0.1).label_for_lm().databunch(bs=48))

# %%
train_data_lm3.save('train_data_lm3.pkl')

# %%
train_data_lm3.vocab.itos[:10]
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxfld',
#  'xxmaj',
#  'xxup',
#  'xxrep',
#  'xxwrep',
#  ',']

# %%
train_data_lm3.train_ds[0][0]
# Out:
# Text xxbos xxmaj australia xxmaj andrew xxmaj peace 2007 xxmaj peace xxmaj family xxmaj vineyard xxmaj chardonnay ( xxmaj south xxmaj eastern xxmaj australia ) xxmaj classic xxmaj chardonnay aromas of apple , pear and hay lead into a palate marked by decent intensity but also a bit of sweetness . xxmaj orange and candy notes run through the rather short finish .

# %%
train_data_lm3 = load_data('', 'train_data_lm3.pkl', bs=48)

# %%
train_data_lm3.show_batch(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2014 xxmaj red ( xxmaj columbia xxmaj valley ( xxup wa ) ) xxmaj this wine is near equal parts xxmaj syrah and xxmaj merlot with the balance xxmaj cabernet xxmaj sauvignon . xxmaj aromas of blue fruit , vanilla , cherry and herb lead to full - bodied pit - fruit flavors that bring a sense of deliciousness that is hard to resist . xxbos xxmaj italy xxmaj renato</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>but the finish is peachy and bright . xxmaj an unusual blend of xxmaj merlot accented with a mélange of other red and white grapes . xxbos xxup us xxmaj xxunk xxmaj xxunk 2013 xxmaj pinot xxmaj noir ( xxmaj russian xxmaj river xxmaj valley ) a small - production xxmaj pinot that 's earthy in just - picked strawberry , this offers light color and smooth , soft ,</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>has lively berry fruits , soft tannins and acidity to match . xxmaj it 's a drink - now wine , the texture open and ready to go . xxbos xxmaj france xxmaj château xxmaj riotor 2016 xxmaj rosé ( xxmaj côtes de xxmaj provence ) xxmaj owned by the xxmaj xxunk family of xxmaj château xxmaj mont - xxmaj redon in xxmaj châteauneuf - du - xxmaj pape ,</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>sees a hearty dose of new oak and is built for the long term . xxmaj it leans classic in its elegant layers of dried herb , red currant and pomegranate flavor . xxmaj boldly structured , it pleases rather than challenges the palate . xxbos xxup us xxmaj sylvester 2007 xxmaj sauvignon xxmaj blanc ( xxmaj california ) xxmaj semisweet and likeable for its crisp , clean mouthfeel ,</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>drink through 2020 . xxbos xxmaj france xxmaj veuve xxmaj doussot 2008 xxmaj xxunk xxmaj brut ( xxmaj champagne ) xxmaj doussot is a producer in the xxmaj aube region in southern xxmaj champagne , which explains the high alcohol for xxmaj champagne . xxmaj however the wine still has all the crisp , mineral character of xxmaj champagne , broadened out with pineapple and ripe orange flavors . xxmaj</td>
#     </tr>
#   </tbody>
# </table>

# %%
languageModel3 = language_model_learner(train_data_lm3, arch=AWD_LSTM, pretrained_fnames=fnames, drop_mult=0.3)

# %%
languageModel3.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='1588' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.23% [99/1588 00:13<03:21 8.5067]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
languageModel3.recorder.plot(skip_end=10)

# %%
languageModel3.fit_one_cycle(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.757910</td>
#       <td>2.634492</td>
#       <td>0.474354</td>
#       <td>03:42</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.622966</td>
#       <td>2.532026</td>
#       <td>0.486505</td>
#       <td>03:41</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.514043</td>
#       <td>2.453246</td>
#       <td>0.495494</td>
#       <td>03:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.399808</td>
#       <td>2.392773</td>
#       <td>0.503645</td>
#       <td>03:40</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.310440</td>
#       <td>2.377941</td>
#       <td>0.506270</td>
#       <td>03:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
#languageModel2.save('fine_tuned2')
languageModel3.save_encoder('fine_tuned_enc3')

# %% [markdown]
# # Classifier Model 3

# %%
data_classifier3 = (TextList.from_df(df=train_data,path='.',cols='all_text_combined1', vocab=train_data_lm3.vocab)
                    .split_by_rand_pct(0.1)
                    .label_from_df('variety')
                    .add_test(test_data)
                    .databunch(bs=48))

# %%
data_classifier3.save('data_classifier3.pkl')

# %%
data_classifier3 = load_data('','data_classifier3.pkl',bs=48)

# %%
data_classifier3.show_batch(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxup us xxmaj meander 2006 xxmaj morisoli xxmaj vineyard xxmaj cabernet xxmaj sauvignon ( xxmaj rutherford ) xxmaj this very fine xxmaj cabernet wants a little time in the cellar . xxmaj right now , it 's tight in tannins , with some acidic bitterness in the finish . xxmaj the flavors are of black currants and smoky new oak . xxmaj the xxmaj morisoli xxmaj vineyard has been</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj south xxmaj africa xxmaj mullineux 2013 xxmaj cape xxmaj winemakers xxmaj guild xxmaj trifecta xxmaj syrah ( xxmaj swartland ) xxmaj winemaker : xxmaj andrea xxmaj mullineux . xxmaj named xxmaj trifecta for the three vineyards — one schist - based , one granite - based and one iron - based — the wine is sourced from , this is an expressive and layered xxmaj syrah . xxmaj</td>
#       <td>Syrah</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj south xxmaj africa xxmaj mvemve xxmaj raats 2012 xxup mr de xxmaj compostella xxmaj red ( xxmaj stellenbosch ) a blend of 28 % xxmaj cabernet xxmaj franc , 23 % xxmaj cabernet xxmaj sauvignon , 21 % xxmaj malbec , 18 % xxmaj petit xxmaj verdot and 10 % xxmaj merlot , this is a big , bold and powerful wine , with superb balance and a</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj woodward xxmaj canyon 2012 xxmaj old xxmaj vines xxmaj cabernet xxmaj sauvignon ( xxmaj washington ) a blend of xxmaj champoux ( 62 % ) , xxmaj sagemoor ( 26 % ) and xxmaj woodward xxmaj canyon ( 12 % ) estate vineyards , this wine is aromatically brooding at present , with notes of coffee , toffee and vanilla bean alongside high - toned cherries</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj betz xxmaj family 2012 xxmaj le xxmaj xxunk xxmaj cabernet xxmaj sauvignon ( xxmaj red xxmaj mountain ) a rare reserve - level xxmaj cabernet only made once before , this 100 % varietal wine hails from esteemed xxmaj kiona and xxmaj ciel du xxmaj cheval vineyards . xxmaj char and dark roasted coffee aromas meld with notes of herbs , spice and black fruit .</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel3 = text_classifier_learner(data_classifier3, arch=AWD_LSTM, drop_mult=0.5)
classifierModel3.load_encoder('fine_tuned_enc3')
classifierModel3.freeze()

# %%
classifierModel3.summary()
# Out:
# SequentialRNN
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# RNNDropout           [57, 400]            0          False
# ______________________________________________________________________
# RNNDropout           [57, 1152]           0          False
# ______________________________________________________________________
# RNNDropout           [57, 1152]           0          False
# ______________________________________________________________________
# BatchNorm1d          [1200]               2,400      True
# ______________________________________________________________________
# Dropout              [1200]               0          False
# ______________________________________________________________________
# Linear               [50]                 60,050     True
# ______________________________________________________________________
# ReLU                 [50]                 0          False
# ______________________________________________________________________
# BatchNorm1d          [50]                 100        True
# ______________________________________________________________________
# Dropout              [50]                 0          False
# ______________________________________________________________________
# Linear               [28]                 1,428      True
# ______________________________________________________________________
#
# Total params: 63,978
# Total trainable params: 63,978
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied
#     RNNTrainer

# %%
classifierModel3.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='95' class='' max='1549' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.13% [95/1549 00:14<03:42 9.7950]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
classifierModel3.recorder.plot()

# %%
classifierModel3.fit_one_cycle(1, 2e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.783377</td>
#       <td>0.370922</td>
#       <td>0.878887</td>
#       <td>02:52</td>
#     </tr>
#   </tbody>
# </table>

# %%
for i in range(2,5):
    classifierModel3.freeze_to(-i)
    classifierModel3.fit_one_cycle(1,slice((1*10**-i)/(2.6**4),1*10**-i))
    print ('')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.158322</td>
#       <td>0.081573</td>
#       <td>0.970720</td>
#       <td>02:58</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.124702</td>
#       <td>0.073973</td>
#       <td>0.975197</td>
#       <td>02:59</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.093111</td>
#       <td>0.072947</td>
#       <td>0.975318</td>
#       <td>03:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel3.recorder.plot_losses()

# %%
classifierModel3.save('classifierModel3')

# %%
train_loss3,train_accuracy3 = classifierModel3.validate(classifierModel3.data.train_dl)

# %%
valid_loss3,valid_accuracy3 = classifierModel3.validate(classifierModel3.data.valid_dl)

# %%
print("Training Accuracy from model 3 is {0}".format(train_accuracy3*100))
print('')
print("Validation Accuracy from model 3 is {0}".format(valid_accuracy3*100))
# Out:
# Training Accuracy from model 3 is 97.78755187988281
#
# Validation Accuracy from model 3 is 97.5317611694336

# %%
classifierModel3.show_results(rows=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj france xxmaj domaine xxmaj zind - xxmaj humbrecht 2015 xxmaj clos xxmaj saint xxmaj urbain xxmaj rangen de xxmaj thann xxmaj grand xxmaj cru xxmaj riesling ( xxmaj alsace ) xxmaj smoke , orange , wet stone and earth notes are powerful and beguiling on the nose . xxmaj the palate has absolute concentration and energy and more of that smoky promise . xxmaj this is like the</td>
#       <td>Riesling</td>
#       <td>Riesling</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj south xxmaj africa xxmaj ernie xxmaj els 2014 xxmaj cape xxmaj winemakers xxmaj guild xxup cwg xxmaj red ( xxmaj stellenbosch ) xxmaj winemaker : xxmaj louis xxmaj xxunk . xxmaj this xxmaj cabernet xxmaj sauvignon - dominant blend , with 30 % xxmaj shiraz and 10 % xxmaj merlot , opens with a lovely mélange of just - ripe aromas of blackberry , cassis and black plum</td>
#       <td>Red Blend</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj france xxmaj domaine xxup g. xxmaj metz 2014 xxmaj muenchberg xxmaj grand xxmaj cru xxmaj riesling ( xxmaj alsace ) xxmaj this combination of tingling grapefruit spice , pure lemon and leafy lemon balm on the nose is utterly disarming . xxmaj the touch of green apple makes it even more alluring . xxmaj the palate xxunk all of these fresh , lithe , bright and appetizing flavors</td>
#       <td>Riesling</td>
#       <td>Riesling</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj austria xxmaj ebner - xxmaj ebenauer 2008 xxmaj blanc de xxmaj blancs xxmaj chardonnay ( xxmaj österreichischer xxmaj sekt ) xxmaj the sumptuous nose immediately signals that this is a special treat : layers of fresh and dried apple melded into autolytic notes of fresh brioche , challah and almond - crusted pastry . xxmaj while the flavors of the palate remain equally sumptuous — introducing an almost</td>
#       <td>Chardonnay</td>
#       <td>Chardonnay</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj france xxmaj piper - xxmaj heidsieck xxup nv xxmaj special xxmaj cuvée xxmaj brut ( xxmaj champagne ) xxmaj the extraordinary package , created by fashion designer xxmaj jean - xxmaj paul xxmaj xxunk , is so over - the - top that it is truly worth xxunk in and of itself . a hand - stitched , red vinyl body suit , tailored to the bottle ’s</td>
#       <td>Champagne Blend</td>
#       <td>Champagne Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj france xxmaj cave de xxmaj ribeauvillé 2010 xxmaj gloeckelberg xxmaj grand xxmaj cru xxmaj pinot xxmaj gris ( xxmaj alsace ) xxmaj the nose already promises both texture and ripeness with its combined aroma of russet pear peel and juicy pear flesh . xxmaj the palate only adds to the juicy richness with a good dollop of residual sweetness , boosting all of the pear fruit . xxmaj</td>
#       <td>Pinot Gris</td>
#       <td>Pinot Gris</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj leonetti xxmaj cellar 2014 xxmaj reserve xxmaj red ( xxmaj walla xxmaj walla xxmaj valley ( xxup wa ) ) xxmaj this wine is a blend of 79 % xxmaj cabernet xxmaj sauvignon , 13 % xxmaj malbec and 8 % xxmaj petit xxmaj verdot from xxmaj seven xxmaj hills , xxmaj loess , xxmaj mill xxmaj creek xxmaj upland and xxmaj serra xxmaj pedace vineyards</td>
#       <td>Bordeaux-style Red Blend</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj france xxmaj biecher &amp; xxmaj schaal 2015 xxmaj rangen de xxmaj thann xxmaj grand xxmaj cru xxmaj riesling ( xxmaj alsace ) a lovely touch of flint and smoke carry a touch of residual reduction . xxmaj underneath that is lemony purity . xxmaj the palate adds a touch of stone fruit , a touch of ripe mirabelle plum — its generosity only underlined by the taut lemon</td>
#       <td>Riesling</td>
#       <td>Riesling</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj trefethen 2008 halo xxmaj cabernet xxmaj sauvignon ( xxmaj oak xxmaj knoll xxmaj district ) xxmaj trefethen has been on a roll the last few years , producing some of xxmaj napa 's most spectacular xxmaj cabernets . xxmaj this bottling , which contains minor quantities of xxmaj petit xxmaj verdot and xxmaj merlot , spent 28 months in new xxmaj french oak barrels . xxmaj</td>
#       <td>Cabernet Sauvignon</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj rodney xxmaj strong 2004 xxmaj symmetry xxmaj meritage xxmaj red ( xxmaj alexander xxmaj valley ) xxmaj strong 's xxmaj symmetry almost qualifies as a xxmaj cabernet xxmaj sauvignon , with 71 % of that variety , and the rest consisting of xxmaj merlot , xxmaj malbec and xxmaj petit xxmaj verdot . xxmaj the xxmaj meritage labeling identifies it as their supreme bottling of a</td>
#       <td>Bordeaux-style Red Blend</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#   </tbody>
# </table>

# %%
preds3 = classifierModel3.get_preds(DatasetType.Test)

# %%
build_submission_file(classifierModel3,preds3,'submission3.csv')
# Out:
#               user_name    country  \
# 0           @paulgwine          US
# 1           @wineschach  Argentina
# 2               @vboone         US
# 3           @wineschach  Argentina
# 4          @kerinokeefe      Italy
# ...                 ...        ...
# 20660  @gordone_cellars         US
# 20661         @laurbuzz     France
# 20662     @mattkettmann         US
# 20663       @wineschach      Spain
# 20664               NaN         US
#
#                                             review_title  \
# 0      Boedecker Cellars 2011 Athena Pinot Noir (Will...
# 1      Mendoza Vineyards 2012 Gran Reserva by Richard...
# 2                    Prime 2013 Chardonnay (Coombsville)
# 3      Bodega Cuarto Dominio 2012 Chento Vineyard Sel...
# 4               SassodiSole 2012  Brunello di Montalcino
# ...                                                  ...
# 20660  Yorkville Cellars 2013 Rennie Vineyard Caberne...
# 20661  Château Ribaute 2015 Senhal d'Aric Rosé (Corbi...
# 20662  Daou 2014 Reserve Cabernet Sauvignon (Paso Rob...
# 20663  Peñascal 2011 Tempranillo Rosé (Vino de la Tie...
# 20664  Langtry 2005 Tephra Ridge Vineyard Cabernet Sa...
#
#                                       review_description  \
# 0      Nicely differentiated from the companion Stewa...
# 1      Charred, smoky, herbal aromas of blackberry tr...
# 2      Slightly sour and funky in earth, this is a re...
# 3      This concentrated, midnight-black Malbec deliv...
# 4      Earthy aromas suggesting grilled porcini, leat...
# ...                                                  ...
# 20660  Clearly focused and fruit-driven, this wine ha...
# 20661  Herbal tones of bay and rosemary are upfront o...
# 20662  Mocha cream, pencil shaving and dried herb aro...
# 20663  Loud citrus and berry aromas precede an overlo...
# 20664  With very ripe fruit and firm tannins, this mo...
#
#                           designation  points  price              province  \
# 0                              Athena      88   35.0                Oregon
# 1      Gran Reserva by Richard Bonvin      90   60.0      Mendoza Province
# 2                                 NaN      87   38.0            California
# 3           Chento Vineyard Selection      91   20.0      Mendoza Province
# 4                                 NaN      90   49.0               Tuscany
# ...                               ...     ...    ...                   ...
# 20660                 Rennie Vineyard      91   34.0            California
# 20661                   Senhal d'Aric      84   20.0  Languedoc-Roussillon
# 20662                         Reserve      94   85.0            California
# 20663                     Tempranillo      80    9.0        Northern Spain
# 20664           Tephra Ridge Vineyard      87   40.0            California
#
#                                    region_1           region_2  \
# 0                         Willamette Valley  Willamette Valley
# 1                                   Mendoza                NaN
# 2                               Coombsville               Napa
# 3                                   Mendoza                NaN
# 4                    Brunello di Montalcino                NaN
# ...                                     ...                ...
# 20660                   Yorkville Highlands        North Coast
# 20661                             Corbières                NaN
# 20662                           Paso Robles      Central Coast
# 20663  Vino de la Tierra de Castilla y León                NaN
# 20664                           Lake County                NaN
#
#                       winery             variety
# 0          Boedecker Cellars          Pinot Noir
# 1          Mendoza Vineyards              Malbec
# 2                      Prime          Chardonnay
# 3      Bodega Cuarto Dominio              Malbec
# 4                SassodiSole          Sangiovese
# ...                      ...                 ...
# 20660      Yorkville Cellars      Cabernet Franc
# 20661        Château Ribaute                Rosé
# 20662                   Daou  Cabernet Sauvignon
# 20663               Peñascal                Rosé
# 20664                Langtry  Cabernet Sauvignon
#
# [20665 rows x 12 columns]

# %%
#classifierModel3.unfreeze()
#classifierModel3.fit_one_cycle(1, slice(1e-5/(2.6**4),1e-3))

# %% [markdown]
# # Language Model 4

# %%
train_data_lm4 = (TextList.from_df(df=train_data,path='.',cols='all_text_combined2').split_by_rand_pct(0.1).label_for_lm().databunch(bs=48))

# %%
train_data_lm4.save('train_data_lm4.pkl')

# %%
train_data_lm4.vocab.itos[:10]
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxfld',
#  'xxmaj',
#  'xxup',
#  'xxrep',
#  'xxwrep',
#  ',']

# %%
train_data_lm4.train_ds[0][0]
# Out:
# Text xxbos xxmaj australia xxmaj australia xxmaj other xxmaj andrew xxmaj peace 2007 xxmaj peace xxmaj family xxmaj vineyard xxmaj chardonnay ( xxmaj south xxmaj eastern xxmaj australia ) xxmaj classic xxmaj chardonnay aromas of apple , pear and hay lead into a palate marked by decent intensity but also a bit of sweetness . xxmaj orange and candy notes run through the rather short finish .

# %%
train_data_lm4 = load_data('', 'train_data_lm4.pkl', bs=48)

# %%
train_data_lm4.show_batch(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>washington xxmaj north by xxmaj northwest 2014 xxmaj red ( xxmaj columbia xxmaj valley ( xxup wa ) ) xxmaj this wine is near equal parts xxmaj syrah and xxmaj merlot with the balance xxmaj cabernet xxmaj sauvignon . xxmaj aromas of blue fruit , vanilla , cherry and herb lead to full - bodied pit - fruit flavors that bring a sense of deliciousness that is hard to resist</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>this firmly structured but accessible red . xxmaj the palate delivers ripe black cherry , red currants and tobacco lightly accented with oak - driven spice . xxmaj it 's balanced with firm , fine - grained tannins . xxmaj drink through 2016 . xxbos xxmaj austria xxmaj niederösterreich xxmaj arndorfer 2013 xxmaj strasser xxmaj weinberge xxmaj riesling ( xxmaj niederösterreich ) xxmaj this suggests freshly baked pear tart with</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>and strawberry and cherry hard candy . xxmaj the fruit is backed with ample tannin , and a warm touch of mocha and toast fills in the finish . xxbos xxup us xxmaj washington xxmaj purple xxmaj star 2009 xxmaj cabernet xxmaj sauvignon ( xxmaj columbia xxmaj valley ( xxup wa ) ) xxmaj this is made from fruit sourced from the xxmaj milbrandt , xxmaj olsen and xxmaj kiona</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>it 's called xxmaj secco , according to the winery , because it 's completely dry . xxmaj maybe so , but there 's plenty of honeyed richness in this delightful xxmaj riesling . xxmaj it shows a wealth of delicious , easy - drinking flavors of orange , apricot , xxmaj key lime pie and vanilla . xxbos xxmaj slovenia xxmaj goriska xxmaj brda xxmaj colliano 2013 xxmaj cuvée</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>de xxmaj tupungato xxmaj red ( xxmaj mendoza ) xxmaj dark in the glass , this has a moderately complex nose , with notes of black fruit , leather and spice . xxmaj it feels tight , fresh and snappy , but not excessively wide or structured . xxmaj flavors of ripe berry and cocoa lead to a solid finish , which has a controlled , smooth feel . a</td>
#     </tr>
#   </tbody>
# </table>

# %%
languageModel4 = language_model_learner(train_data_lm4, arch=AWD_LSTM, pretrained_fnames=fnames, drop_mult=0.3)

# %%
languageModel4.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='1642' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.03% [99/1642 00:13<03:29 8.2854]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
languageModel4.recorder.plot(skip_end=10)

# %%
languageModel4.fit_one_cycle(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.672374</td>
#       <td>2.559166</td>
#       <td>0.485467</td>
#       <td>03:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.555732</td>
#       <td>2.454422</td>
#       <td>0.497191</td>
#       <td>03:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.437539</td>
#       <td>2.380009</td>
#       <td>0.506138</td>
#       <td>03:51</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.320478</td>
#       <td>2.319516</td>
#       <td>0.514165</td>
#       <td>03:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.236712</td>
#       <td>2.305316</td>
#       <td>0.515837</td>
#       <td>03:49</td>
#     </tr>
#   </tbody>
# </table>

# %%
#languageModel2.save('fine_tuned2')
languageModel4.save_encoder('fine_tuned_enc4')

# %% [markdown]
# # Classifier Model 4

# %%
data_classifier4 = (TextList.from_df(df=train_data,path='.',cols='all_text_combined2', vocab=train_data_lm4.vocab)
                    .split_by_rand_pct(0.1)
                    .label_from_df('variety')
                    .add_test(test_data)
                    .databunch(bs=48))

# %%
data_classifier4.save('data_classifier4.pkl')

# %%
data_classifier4 = load_data('','data_classifier4.pkl',bs=48)

# %%
data_classifier4.show_batch(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxup us xxmaj washington xxmaj saggi 2007 xxmaj red ( xxmaj columbia xxmaj valley ( xxup wa ) ) xxmaj dark , dusty , strongly scented with barrel toast , coffee grounds and incense , this is the most substantial and complete version to date . xxmaj balancing cherry and plum fruit against the pretty barrel - infused tannins , it glides gracefully across the palate into a seamless</td>
#       <td>Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj oregon xxmaj lemelson 2006 xxmaj jerome xxmaj reserve xxmaj pinot xxmaj noir ( xxmaj willamette xxmaj valley ) xxmaj this complex wine lists no fewer than eight different clones in the blend , harvested at an average of just xxunk tons / acre . xxmaj the winery suggests that it is their most ageworthy xxmaj pinot xxmaj noir , and the structure of this young wine</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj yao xxmaj ming 2009 xxmaj family xxmaj reserve xxmaj cabernet xxmaj sauvignon ( xxmaj napa xxmaj valley ) xxmaj the former xxunk star 's initial release immediately xxunk itself among the elite xxmaj cabernets of xxmaj napa xxmaj valley . xxmaj made from mountain vineyards on xxmaj atlas xxmaj peak and benches in the xxmaj rutherford appellation , it combines intensity with elegance .</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj washington 21 xxmaj grams 2011 xxmaj red ( xxmaj washington ) xxmaj this wine is mostly xxmaj cabernet xxmaj sauvignon ( 85 % ) along with 9 % xxmaj petit xxmaj verdot and 6 % xxmaj malbec , with most of the fruit coming from top sites of xxmaj cold xxmaj creek xxmaj vineyard and xxmaj stone xxmaj tree vineyards . xxmaj tightly wound up right</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj trefethen 2008 halo xxmaj cabernet xxmaj sauvignon ( xxmaj oak xxmaj knoll xxmaj district ) xxmaj trefethen has been on a roll the last few years , producing some of xxmaj napa 's most spectacular xxmaj cabernets . xxmaj this bottling , which contains minor quantities of xxmaj petit xxmaj verdot and xxmaj merlot , spent 28 months in new xxmaj french oak barrels</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel4 = text_classifier_learner(data_classifier4, arch=AWD_LSTM, drop_mult=0.5)
classifierModel4.load_encoder('fine_tuned_enc4')
classifierModel4.freeze()

# %%
classifierModel4.summary()
# Out:
# SequentialRNN
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# RNNDropout           [54, 400]            0          False
# ______________________________________________________________________
# RNNDropout           [54, 1152]           0          False
# ______________________________________________________________________
# RNNDropout           [54, 1152]           0          False
# ______________________________________________________________________
# BatchNorm1d          [1200]               2,400      True
# ______________________________________________________________________
# Dropout              [1200]               0          False
# ______________________________________________________________________
# Linear               [50]                 60,050     True
# ______________________________________________________________________
# ReLU                 [50]                 0          False
# ______________________________________________________________________
# BatchNorm1d          [50]                 100        True
# ______________________________________________________________________
# Dropout              [50]                 0          False
# ______________________________________________________________________
# Linear               [28]                 1,428      True
# ______________________________________________________________________
#
# Total params: 63,978
# Total trainable params: 63,978
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied
#     RNNTrainer

# %%
classifierModel4.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='96' class='' max='1549' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.20% [96/1549 00:15<03:55 10.5853]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
classifierModel4.recorder.plot()

# %%
classifierModel4.fit_one_cycle(1, 2e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.772575</td>
#       <td>0.370088</td>
#       <td>0.884453</td>
#       <td>03:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
for i in range(2,5):
    classifierModel4.freeze_to(-i)
    classifierModel4.fit_one_cycle(1,slice((1*10**-i)/(2.6**4),1*10**-i))
    print ('')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.158414</td>
#       <td>0.077529</td>
#       <td>0.973745</td>
#       <td>02:57</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.116977</td>
#       <td>0.066249</td>
#       <td>0.977979</td>
#       <td>03:11</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.110679</td>
#       <td>0.065736</td>
#       <td>0.977374</td>
#       <td>03:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel4.recorder.plot_losses()

# %%
classifierModel4.save('classifierModel4')

# %%
train_loss4,train_accuracy4 = classifierModel4.validate(classifierModel4.data.train_dl)

# %%
valid_loss4,valid_accuracy4 = classifierModel4.validate(classifierModel4.data.valid_dl)

# %%
print("Training Accuracy from model 4 is {0}".format(train_accuracy4*100))
print('')
print("Validation Accuracy from model 4 is {0}".format(valid_accuracy4*100))
# Out:
# Training Accuracy from model 4 is 97.83328247070312
#
# Validation Accuracy from model 4 is 97.7374496459961

# %%
classifierModel4.show_results(rows=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj meander 2006 xxmaj morisoli xxmaj vineyard xxmaj cabernet xxmaj sauvignon ( xxmaj rutherford ) xxmaj this very fine xxmaj cabernet wants a little time in the cellar . xxmaj right now , it 's tight in tannins , with some acidic bitterness in the finish . xxmaj the flavors are of black currants and smoky new oak . xxmaj the xxmaj morisoli xxmaj vineyard</td>
#       <td>Cabernet Sauvignon</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj williams xxmaj selyem 2010 30th xxmaj anniversary xxmaj cuvée xxmaj estate xxmaj vineyard xxmaj pinot xxmaj noir ( xxmaj russian xxmaj river xxmaj valley ) xxmaj this is a xxmaj pinot xxmaj noir of considerable force . xxmaj your first impression is of xxunk power , with masses of fruit punching through an overlay of tannin and oak . xxmaj then the flavors fantail</td>
#       <td>Pinot Noir</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj schramsberg 2004 xxmaj reserve xxmaj sparkling ( xxmaj napa - xxmaj mendocino - xxmaj sonoma - xxmaj marin ) xxmaj the opulence of this sparkling wine has to be tasted to be believed . xxmaj it 's far softer and silkier than the winery 's companion new release , the 2005 xxup j. xxmaj schram , but then the blend is the complete opposite</td>
#       <td>Sparkling Blend</td>
#       <td>Sparkling Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj failla 2010 xxmaj hirsch xxmaj vineyard xxmaj pinot xxmaj noir ( xxmaj sonoma xxmaj coast ) xxmaj this shows the trifecta of winemaker xxmaj ehren xxmaj jordan 's deft hand , the fabulous xxmaj hirsch xxmaj vineyard and the wonderful 2010 vintage . xxmaj even if you knew nothing of the wine 's pedigree , you 'd be dazzled by its sheer richness of</td>
#       <td>Pinot Noir</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj south xxmaj africa xxmaj elgin xxmaj paul xxmaj cluver 2016 xxmaj cape xxmaj winemakers xxmaj guild xxmaj the xxmaj wagon xxmaj trail xxmaj chardonnay ( xxmaj elgin ) xxmaj winemaker : xxmaj andries xxmaj burger . xxmaj always a stunner , the 2016 xxmaj wagon xxmaj trail delivers impeccable balance , freshness and minerality that can easily translate in the wine being mistaken for one from another iconic</td>
#       <td>Chardonnay</td>
#       <td>Chardonnay</td>
#     </tr>
#     <tr>
#       <td>xxbos unknown unknown xxmaj newton xxmaj johnson 2016 xxmaj cape xxmaj winemakers xxmaj guild xxmaj xxunk xxmaj pinot xxmaj noir xxmaj winemaker : xxmaj gordon xxmaj newton xxmaj johnson . xxmaj this is such a pretty and elegant xxmaj pinot , certainly not what most would expect from a " xxmaj new xxmaj world " wine region . xxmaj it expresses the masterful balance that xxmaj south xxmaj african xxmaj</td>
#       <td>Pinot Noir</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj joseph xxmaj phelps 2009 xxmaj insignia xxmaj estate xxmaj grown xxmaj red ( xxmaj napa xxmaj valley ) xxmaj this wine continues a long - standing tradition , showing a mastery of the art of blending . xxmaj it 's made using grapes that are sourced from at least six vineyards scattered from xxmaj yountville to xxmaj st. xxmaj helena . xxmaj right out</td>
#       <td>Red Blend</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj france xxmaj alsace xxmaj domaine xxmaj schoffit 2012 xxmaj clos xxmaj saint - xxmaj théobald xxmaj rangen xxmaj grand xxmaj cru xxmaj sélection de xxmaj grains xxmaj nobles xxmaj pinot xxmaj gris ( xxmaj alsace ) xxmaj the musky touch of botrytized fruit appears immediately , adding even more allure to the golden color . xxmaj an explosion of golden apricot and luscious peach provide mouthfilling sweetness on</td>
#       <td>Pinot Gris</td>
#       <td>Pinot Gris</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj france xxmaj alsace xxmaj domaine xxmaj zind - xxmaj humbrecht 2013 xxmaj clos xxmaj saint xxmaj urbain xxmaj rangen de xxmaj thann xxmaj grand xxmaj cru xxmaj riesling ( xxmaj alsace ) xxmaj subtle smoke hovers above earthy notes and the nose only holds the faintest suggestion of citrus . xxmaj the palate comes forth with a vivid , leafy purity that suggests herbs , freshly turned earth</td>
#       <td>Riesling</td>
#       <td>Riesling</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj wood xxmaj family xxmaj vineyards 2007 xxmaj madden xxmaj ranch xxmaj syrah ( xxmaj livermore xxmaj valley ) xxmaj the grapes for this immense , rich blueberry jammy xxmaj syrah come from xxup xxunk 's xxmaj john xxmaj madden 's ranch . xxmaj it 's as big and loud as he can be , with not quite enough fruit or acid to overcome the</td>
#       <td>Syrah</td>
#       <td>Syrah</td>
#     </tr>
#   </tbody>
# </table>

# %%
preds4 = classifierModel4.get_preds(DatasetType.Test)

# %%
build_submission_file(classifierModel4,preds4,'submission4.csv')
# Out:
#               user_name    country  \
# 0           @paulgwine          US
# 1           @wineschach  Argentina
# 2               @vboone         US
# 3           @wineschach  Argentina
# 4          @kerinokeefe      Italy
# ...                 ...        ...
# 20660  @gordone_cellars         US
# 20661         @laurbuzz     France
# 20662     @mattkettmann         US
# 20663       @wineschach      Spain
# 20664               NaN         US
#
#                                             review_title  \
# 0      Boedecker Cellars 2011 Athena Pinot Noir (Will...
# 1      Mendoza Vineyards 2012 Gran Reserva by Richard...
# 2                    Prime 2013 Chardonnay (Coombsville)
# 3      Bodega Cuarto Dominio 2012 Chento Vineyard Sel...
# 4               SassodiSole 2012  Brunello di Montalcino
# ...                                                  ...
# 20660  Yorkville Cellars 2013 Rennie Vineyard Caberne...
# 20661  Château Ribaute 2015 Senhal d'Aric Rosé (Corbi...
# 20662  Daou 2014 Reserve Cabernet Sauvignon (Paso Rob...
# 20663  Peñascal 2011 Tempranillo Rosé (Vino de la Tie...
# 20664  Langtry 2005 Tephra Ridge Vineyard Cabernet Sa...
#
#                                       review_description  \
# 0      Nicely differentiated from the companion Stewa...
# 1      Charred, smoky, herbal aromas of blackberry tr...
# 2      Slightly sour and funky in earth, this is a re...
# 3      This concentrated, midnight-black Malbec deliv...
# 4      Earthy aromas suggesting grilled porcini, leat...
# ...                                                  ...
# 20660  Clearly focused and fruit-driven, this wine ha...
# 20661  Herbal tones of bay and rosemary are upfront o...
# 20662  Mocha cream, pencil shaving and dried herb aro...
# 20663  Loud citrus and berry aromas precede an overlo...
# 20664  With very ripe fruit and firm tannins, this mo...
#
#                           designation  points  price              province  \
# 0                              Athena      88   35.0                Oregon
# 1      Gran Reserva by Richard Bonvin      90   60.0      Mendoza Province
# 2                                 NaN      87   38.0            California
# 3           Chento Vineyard Selection      91   20.0      Mendoza Province
# 4                                 NaN      90   49.0               Tuscany
# ...                               ...     ...    ...                   ...
# 20660                 Rennie Vineyard      91   34.0            California
# 20661                   Senhal d'Aric      84   20.0  Languedoc-Roussillon
# 20662                         Reserve      94   85.0            California
# 20663                     Tempranillo      80    9.0        Northern Spain
# 20664           Tephra Ridge Vineyard      87   40.0            California
#
#                                    region_1           region_2  \
# 0                         Willamette Valley  Willamette Valley
# 1                                   Mendoza                NaN
# 2                               Coombsville               Napa
# 3                                   Mendoza                NaN
# 4                    Brunello di Montalcino                NaN
# ...                                     ...                ...
# 20660                   Yorkville Highlands        North Coast
# 20661                             Corbières                NaN
# 20662                           Paso Robles      Central Coast
# 20663  Vino de la Tierra de Castilla y León                NaN
# 20664                           Lake County                NaN
#
#                       winery             variety
# 0          Boedecker Cellars          Pinot Noir
# 1          Mendoza Vineyards              Malbec
# 2                      Prime          Chardonnay
# 3      Bodega Cuarto Dominio              Malbec
# 4                SassodiSole          Sangiovese
# ...                      ...                 ...
# 20660      Yorkville Cellars      Cabernet Franc
# 20661        Château Ribaute                Rosé
# 20662                   Daou  Cabernet Sauvignon
# 20663               Peñascal                Rosé
# 20664                Langtry  Cabernet Sauvignon
#
# [20665 rows x 12 columns]

# %%
#classifierModel4.unfreeze()
#classifierModel4.fit_one_cycle(1, slice(1e-5/(2.6**4),1e-3))

# %% [markdown]
# # Language Model 5

# %%
train_data_lm5 = (TextList.from_df(df=train_data,path='.',cols='all_text_combined3').split_by_rand_pct(0.1).label_for_lm().databunch(bs=48))

# %%
train_data_lm5.save('train_data_lm5.pkl')

# %%
train_data_lm5.vocab.itos[:10]
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxfld',
#  'xxmaj',
#  'xxup',
#  'xxrep',
#  'xxwrep',
#  ',']

# %%
train_data_lm5.train_ds[0][0]
# Out:
# Text xxbos xxmaj australia xxmaj australia xxmaj other xxmaj south xxmaj eastern xxmaj australia xxmaj andrew xxmaj peace 2007 xxmaj peace xxmaj family xxmaj vineyard xxmaj chardonnay ( xxmaj south xxmaj eastern xxmaj australia ) xxmaj classic xxmaj chardonnay aromas of apple , pear and hay lead into a palate marked by decent intensity but also a bit of sweetness . xxmaj orange and candy notes run through the rather short finish .

# %%
train_data_lm5 = load_data('', 'train_data_lm5.pkl', bs=48)

# %%
train_data_lm5.show_batch(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>finish . xxbos xxup us xxmaj washington xxmaj columbia xxmaj valley ( xxup wa ) xxmaj north by xxmaj northwest 2014 xxmaj red ( xxmaj columbia xxmaj valley ( xxup wa ) ) xxmaj this wine is near equal parts xxmaj syrah and xxmaj merlot with the balance xxmaj cabernet xxmaj sauvignon . xxmaj aromas of blue fruit , vanilla , cherry and herb lead to full - bodied pit</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>therra xxmaj red ( xxmaj toscana ) xxmaj montepulciano , xxmaj sangiovese , xxmaj merlot and xxmaj cabernet xxmaj sauvignon grapes team up to produce this firmly structured but accessible red . xxmaj the palate delivers ripe black cherry , red currants and tobacco lightly accented with oak - driven spice . xxmaj it 's balanced with firm , fine - grained tannins . xxmaj drink through 2016 . xxbos</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>purple xxmaj star 2009 xxmaj cabernet xxmaj sauvignon ( xxmaj columbia xxmaj valley ( xxup wa ) ) xxmaj this is made from fruit sourced from the xxmaj milbrandt , xxmaj olsen and xxmaj kiona vineyards , which are located in three different avas . xxmaj the wine is packed with black fruit , with light accents of smoke , toast , espresso and dark chocolate that add interest to</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>xxmaj virginia ) xxmaj typical of the variety , this shows upfront aromas of fresh green pepper , eucalyptus , black pepper and blackberry . xxmaj these notes are amplified on the palate , with cedar and earthiness adding dimension . xxmaj the tannins are not shy , but are well - integrated and the acidity is zippy and playful , which lends to a long , enticing finish .</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>sweet spots . xxmaj it 's honeyed in tropical fruits , with oaky notes of buttered toast and vanilla . xxmaj the best thing is the clean , zesty acidity . xxbos xxup us xxmaj california xxmaj sonoma xxmaj valley xxmaj kunde 2007 xxmaj chardonnay ( xxmaj sonoma xxmaj valley ) xxmaj the wine brims with pineapples , xxmaj asian pears and papayas , dusted with every spice in your</td>
#     </tr>
#   </tbody>
# </table>

# %%
languageModel5 = language_model_learner(train_data_lm5, arch=AWD_LSTM, pretrained_fnames=fnames, drop_mult=0.3)

# %%
languageModel5.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='1723' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       5.75% [99/1723 00:13<03:40 8.5277]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
languageModel5.recorder.plot(skip_end=10)

# %%
languageModel5.fit_one_cycle(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.562799</td>
#       <td>2.452955</td>
#       <td>0.505875</td>
#       <td>04:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.452063</td>
#       <td>2.353936</td>
#       <td>0.516226</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.339537</td>
#       <td>2.280161</td>
#       <td>0.524440</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.221418</td>
#       <td>2.220637</td>
#       <td>0.532089</td>
#       <td>04:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.148481</td>
#       <td>2.206352</td>
#       <td>0.534707</td>
#       <td>04:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
#languageModel2.save('fine_tuned2')
languageModel5.save_encoder('fine_tuned_enc5')

# %% [markdown]
# # Classifier Model 5

# %%
data_classifier5 = (TextList.from_df(df=train_data,path='.',cols='all_text_combined3', vocab=train_data_lm5.vocab)
                    .split_by_rand_pct(0.1)
                    .label_from_df('variety')
                    .add_test(test_data)
                    .databunch(bs=48))

# %%
data_classifier5.save('data_classifier5.pkl')

# %%
data_classifier5 = load_data('','data_classifier5.pkl',bs=48)

# %%
data_classifier5.show_batch(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxup us xxmaj washington xxmaj columbia xxmaj valley ( xxup wa ) xxmaj saggi 2007 xxmaj red ( xxmaj columbia xxmaj valley ( xxup wa ) ) xxmaj dark , dusty , strongly scented with barrel toast , coffee grounds and incense , this is the most substantial and complete version to date . xxmaj balancing cherry and plum fruit against the pretty barrel - infused tannins , it</td>
#       <td>Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj oregon xxmaj willamette xxmaj valley xxmaj lemelson 2006 xxmaj jerome xxmaj reserve xxmaj pinot xxmaj noir ( xxmaj willamette xxmaj valley ) xxmaj this complex wine lists no fewer than eight different clones in the blend , harvested at an average of just xxunk tons / acre . xxmaj the winery suggests that it is their most ageworthy xxmaj pinot xxmaj noir , and the structure</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj oak xxmaj knoll xxmaj district xxmaj trefethen 2008 halo xxmaj cabernet xxmaj sauvignon ( xxmaj oak xxmaj knoll xxmaj district ) xxmaj trefethen has been on a roll the last few years , producing some of xxmaj napa 's most spectacular xxmaj cabernets . xxmaj this bottling , which contains minor quantities of xxmaj petit xxmaj verdot and xxmaj merlot , spent 28 months</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj napa xxmaj valley xxmaj yao xxmaj ming 2009 xxmaj family xxmaj reserve xxmaj cabernet xxmaj sauvignon ( xxmaj napa xxmaj valley ) xxmaj the former xxunk star 's initial release immediately xxunk itself among the elite xxmaj cabernets of xxmaj napa xxmaj valley . xxmaj made from mountain vineyards on xxmaj atlas xxmaj peak and benches in the xxmaj rutherford appellation , it combines</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj santa xxmaj lucia xxmaj highlands xxmaj windstream 2012 xxmaj sarmento xxmaj vineyard xxmaj pinot xxmaj noir ( xxmaj santa xxmaj lucia xxmaj highlands ) xxmaj while this bottling is always interesting , it is dependent on vintage conditions . xxmaj this bottling , from the excellent 2012 harvest , is xxmaj windstream 's best ever , a provocative example of a cool - climate</td>
#       <td>Pinot Noir</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel5 = text_classifier_learner(data_classifier5, arch=AWD_LSTM, drop_mult=0.5)
classifierModel5.load_encoder('fine_tuned_enc5')
classifierModel5.freeze()

# %%
classifierModel5.summary()
# Out:
# SequentialRNN
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# RNNDropout           [62, 400]            0          False
# ______________________________________________________________________
# RNNDropout           [62, 1152]           0          False
# ______________________________________________________________________
# RNNDropout           [62, 1152]           0          False
# ______________________________________________________________________
# BatchNorm1d          [1200]               2,400      True
# ______________________________________________________________________
# Dropout              [1200]               0          False
# ______________________________________________________________________
# Linear               [50]                 60,050     True
# ______________________________________________________________________
# ReLU                 [50]                 0          False
# ______________________________________________________________________
# BatchNorm1d          [50]                 100        True
# ______________________________________________________________________
# Dropout              [50]                 0          False
# ______________________________________________________________________
# Linear               [28]                 1,428      True
# ______________________________________________________________________
#
# Total params: 63,978
# Total trainable params: 63,978
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied
#     RNNTrainer

# %%
classifierModel5.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='95' class='' max='1549' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.13% [95/1549 00:15<04:02 7.9795]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
classifierModel5.recorder.plot()

# %%
classifierModel5.fit_one_cycle(1, 2e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.822596</td>
#       <td>0.414728</td>
#       <td>0.868603</td>
#       <td>03:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
for i in range(2,5):
    classifierModel5.freeze_to(-i)
    classifierModel5.fit_one_cycle(1,slice((1*10**-i)/(2.6**4),1*10**-i))
    print ('')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.145571</td>
#       <td>0.078137</td>
#       <td>0.972656</td>
#       <td>03:06</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.113564</td>
#       <td>0.064929</td>
#       <td>0.977253</td>
#       <td>03:20</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.107782</td>
#       <td>0.062917</td>
#       <td>0.978221</td>
#       <td>03:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel5.recorder.plot_losses()

# %%
classifierModel5.save('classifierModel5')

# %%
train_loss5,train_accuracy5 = classifierModel5.validate(classifierModel5.data.train_dl)

# %%
valid_loss5,valid_accuracy5 = classifierModel5.validate(classifierModel5.data.valid_dl)

# %%
print("Training Accuracy from model 5 is {0}".format(train_accuracy5*100))
print('')
print("Validation Accuracy from model 5 is {0}".format(valid_accuracy5*100))
# Out:
# Training Accuracy from model 5 is 97.8951416015625
#
# Validation Accuracy from model 5 is 97.8221435546875

# %%
classifierModel5.show_results(rows=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj rutherford xxmaj meander 2006 xxmaj morisoli xxmaj vineyard xxmaj cabernet xxmaj sauvignon ( xxmaj rutherford ) xxmaj this very fine xxmaj cabernet wants a little time in the cellar . xxmaj right now , it 's tight in tannins , with some acidic bitterness in the finish . xxmaj the flavors are of black currants and smoky new oak . xxmaj the xxmaj morisoli</td>
#       <td>Cabernet Sauvignon</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj russian xxmaj river xxmaj valley xxmaj williams xxmaj selyem 2010 30th xxmaj anniversary xxmaj cuvée xxmaj estate xxmaj vineyard xxmaj pinot xxmaj noir ( xxmaj russian xxmaj river xxmaj valley ) xxmaj this is a xxmaj pinot xxmaj noir of considerable force . xxmaj your first impression is of xxunk power , with masses of fruit punching through an overlay of tannin and oak</td>
#       <td>Pinot Noir</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj napa - xxmaj mendocino - xxmaj sonoma - xxmaj marin xxmaj schramsberg 2004 xxmaj reserve xxmaj sparkling ( xxmaj napa - xxmaj mendocino - xxmaj sonoma - xxmaj marin ) xxmaj the opulence of this sparkling wine has to be tasted to be believed . xxmaj it 's far softer and silkier than the winery 's companion new release , the 2005 xxup j.</td>
#       <td>Sparkling Blend</td>
#       <td>Sparkling Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj sonoma xxmaj coast xxmaj failla 2010 xxmaj hirsch xxmaj vineyard xxmaj pinot xxmaj noir ( xxmaj sonoma xxmaj coast ) xxmaj this shows the trifecta of winemaker xxmaj ehren xxmaj jordan 's deft hand , the fabulous xxmaj hirsch xxmaj vineyard and the wonderful 2010 vintage . xxmaj even if you knew nothing of the wine 's pedigree , you 'd be dazzled by</td>
#       <td>Pinot Noir</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj south xxmaj africa xxmaj elgin unknown xxmaj paul xxmaj cluver 2016 xxmaj cape xxmaj winemakers xxmaj guild xxmaj the xxmaj wagon xxmaj trail xxmaj chardonnay ( xxmaj elgin ) xxmaj winemaker : xxmaj andries xxmaj burger . xxmaj always a stunner , the 2016 xxmaj wagon xxmaj trail delivers impeccable balance , freshness and minerality that can easily translate in the wine being mistaken for one from another</td>
#       <td>Chardonnay</td>
#       <td>Chardonnay</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj napa xxmaj valley xxmaj joseph xxmaj phelps 2009 xxmaj insignia xxmaj estate xxmaj grown xxmaj red ( xxmaj napa xxmaj valley ) xxmaj this wine continues a long - standing tradition , showing a mastery of the art of blending . xxmaj it 's made using grapes that are sourced from at least six vineyards scattered from xxmaj yountville to xxmaj st. xxmaj helena</td>
#       <td>Red Blend</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos unknown unknown unknown xxmaj newton xxmaj johnson 2016 xxmaj cape xxmaj winemakers xxmaj guild xxmaj xxunk xxmaj pinot xxmaj noir xxmaj winemaker : xxmaj gordon xxmaj newton xxmaj johnson . xxmaj this is such a pretty and elegant xxmaj pinot , certainly not what most would expect from a " xxmaj new xxmaj world " wine region . xxmaj it expresses the masterful balance that xxmaj south xxmaj african</td>
#       <td>Pinot Noir</td>
#       <td>Pinot Noir</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj france xxmaj alsace xxmaj alsace xxmaj domaine xxmaj schoffit 2012 xxmaj clos xxmaj saint - xxmaj théobald xxmaj rangen xxmaj grand xxmaj cru xxmaj sélection de xxmaj grains xxmaj nobles xxmaj pinot xxmaj gris ( xxmaj alsace ) xxmaj the musky touch of botrytized fruit appears immediately , adding even more allure to the golden color . xxmaj an explosion of golden apricot and luscious peach provide mouthfilling</td>
#       <td>Pinot Gris</td>
#       <td>Pinot Gris</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj france xxmaj languedoc - xxmaj roussillon xxmaj coteaux du xxmaj languedoc xxmaj gérard xxmaj bertrand 2014 xxmaj château xxmaj la xxmaj sauvageonne xxup xxunk xxmaj rosé ( xxmaj coteaux du xxmaj languedoc ) xxmaj this interesting and complex rosé — made from 65 % xxmaj grenache , 25 % xxmaj mourvèdre , 7 % xxmaj vermentino and 3 % xxmaj viognier — is aged for six months in</td>
#       <td>Rosé</td>
#       <td>Rosé</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup us xxmaj california xxmaj livermore xxmaj valley xxmaj wood xxmaj family xxmaj vineyards 2007 xxmaj madden xxmaj ranch xxmaj syrah ( xxmaj livermore xxmaj valley ) xxmaj the grapes for this immense , rich blueberry jammy xxmaj syrah come from xxup xxunk 's xxmaj john xxmaj madden 's ranch . xxmaj it 's as big and loud as he can be , with not quite enough fruit or</td>
#       <td>Syrah</td>
#       <td>Syrah</td>
#     </tr>
#   </tbody>
# </table>

# %%
preds5 = classifierModel5.get_preds(DatasetType.Test)

# %%
build_submission_file(classifierModel5,preds5,'submission5.csv')
# Out:
#               user_name    country  \
# 0           @paulgwine          US
# 1           @wineschach  Argentina
# 2               @vboone         US
# 3           @wineschach  Argentina
# 4          @kerinokeefe      Italy
# ...                 ...        ...
# 20660  @gordone_cellars         US
# 20661         @laurbuzz     France
# 20662     @mattkettmann         US
# 20663       @wineschach      Spain
# 20664               NaN         US
#
#                                             review_title  \
# 0      Boedecker Cellars 2011 Athena Pinot Noir (Will...
# 1      Mendoza Vineyards 2012 Gran Reserva by Richard...
# 2                    Prime 2013 Chardonnay (Coombsville)
# 3      Bodega Cuarto Dominio 2012 Chento Vineyard Sel...
# 4               SassodiSole 2012  Brunello di Montalcino
# ...                                                  ...
# 20660  Yorkville Cellars 2013 Rennie Vineyard Caberne...
# 20661  Château Ribaute 2015 Senhal d'Aric Rosé (Corbi...
# 20662  Daou 2014 Reserve Cabernet Sauvignon (Paso Rob...
# 20663  Peñascal 2011 Tempranillo Rosé (Vino de la Tie...
# 20664  Langtry 2005 Tephra Ridge Vineyard Cabernet Sa...
#
#                                       review_description  \
# 0      Nicely differentiated from the companion Stewa...
# 1      Charred, smoky, herbal aromas of blackberry tr...
# 2      Slightly sour and funky in earth, this is a re...
# 3      This concentrated, midnight-black Malbec deliv...
# 4      Earthy aromas suggesting grilled porcini, leat...
# ...                                                  ...
# 20660  Clearly focused and fruit-driven, this wine ha...
# 20661  Herbal tones of bay and rosemary are upfront o...
# 20662  Mocha cream, pencil shaving and dried herb aro...
# 20663  Loud citrus and berry aromas precede an overlo...
# 20664  With very ripe fruit and firm tannins, this mo...
#
#                           designation  points  price              province  \
# 0                              Athena      88   35.0                Oregon
# 1      Gran Reserva by Richard Bonvin      90   60.0      Mendoza Province
# 2                                 NaN      87   38.0            California
# 3           Chento Vineyard Selection      91   20.0      Mendoza Province
# 4                                 NaN      90   49.0               Tuscany
# ...                               ...     ...    ...                   ...
# 20660                 Rennie Vineyard      91   34.0            California
# 20661                   Senhal d'Aric      84   20.0  Languedoc-Roussillon
# 20662                         Reserve      94   85.0            California
# 20663                     Tempranillo      80    9.0        Northern Spain
# 20664           Tephra Ridge Vineyard      87   40.0            California
#
#                                    region_1           region_2  \
# 0                         Willamette Valley  Willamette Valley
# 1                                   Mendoza                NaN
# 2                               Coombsville               Napa
# 3                                   Mendoza                NaN
# 4                    Brunello di Montalcino                NaN
# ...                                     ...                ...
# 20660                   Yorkville Highlands        North Coast
# 20661                             Corbières                NaN
# 20662                           Paso Robles      Central Coast
# 20663  Vino de la Tierra de Castilla y León                NaN
# 20664                           Lake County                NaN
#
#                       winery             variety
# 0          Boedecker Cellars          Pinot Noir
# 1          Mendoza Vineyards              Malbec
# 2                      Prime          Chardonnay
# 3      Bodega Cuarto Dominio              Malbec
# 4                SassodiSole          Sangiovese
# ...                      ...                 ...
# 20660      Yorkville Cellars      Cabernet Franc
# 20661        Château Ribaute                Rosé
# 20662                   Daou  Cabernet Sauvignon
# 20663               Peñascal                Rosé
# 20664                Langtry  Cabernet Sauvignon
#
# [20665 rows x 12 columns]

# %%
classifierModel5.unfreeze() #more epochs to check if accuracy improves
classifierModel5.fit_one_cycle(1, slice(1e-5/(2.6**4),1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.103240</td>
#       <td>0.062370</td>
#       <td>0.979189</td>
#       <td>03:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel5.unfreeze() #more epochs to check if accuracy improves
classifierModel5.fit_one_cycle(1, slice(1e-5/(2.6**4),1e-3))

# %% [markdown]
# # Language Model 6

# %%
train_data_lm6 = (TextList.from_df(df=train_data,path='.',cols='all_text_combined4').split_by_rand_pct(0.1).label_for_lm().databunch(bs=48))

# %%
os.remove("/kaggle/working/train_data_lm1.pkl")  #storage space issue on kaggle
os.remove("/kaggle/working/train_data_lm2.pkl")
os.remove("/kaggle/working/train_data_lm3.pkl")
os.remove("/kaggle/working/train_data_lm4.pkl")
train_data_lm6.save('train_data_lm6.pkl')

# %%
train_data_lm6.vocab.itos[:10]
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxfld',
#  'xxmaj',
#  'xxup',
#  'xxrep',
#  'xxwrep',
#  ',']

# %%
train_data_lm6.train_ds[0][0]
# Out:
# Text xxbos xxmaj high xxmaj andrew xxmaj peace 2007 xxmaj peace xxmaj family xxmaj vineyard xxmaj chardonnay ( xxmaj south xxmaj eastern xxmaj australia ) xxmaj classic xxmaj chardonnay aromas of apple , pear and hay lead into a palate marked by decent intensity but also a bit of sweetness . xxmaj orange and candy notes run through the rather short finish .

# %%
train_data_lm6 = load_data('', 'train_data_lm6.pkl', bs=48)

# %%
train_data_lm6.show_batch(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2014 xxmaj red ( xxmaj columbia xxmaj valley ( xxup wa ) ) xxmaj this wine is near equal parts xxmaj syrah and xxmaj merlot with the balance xxmaj cabernet xxmaj sauvignon . xxmaj aromas of blue fruit , vanilla , cherry and herb lead to full - bodied pit - fruit flavors that bring a sense of deliciousness that is hard to resist . xxbos xxmaj medium xxmaj renato</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>of acidity . xxmaj wait for two years , although it is drinkable now . xxbos xxmaj medium podernuovo a xxmaj palazzone 2011 xxmaj therra xxmaj red ( xxmaj toscana ) xxmaj montepulciano , xxmaj sangiovese , xxmaj merlot and xxmaj cabernet xxmaj sauvignon grapes team up to produce this firmly structured but accessible red . xxmaj the palate delivers ripe black cherry , red currants and tobacco lightly accented</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>, there 's plenty to like in the mix of orange flesh and rind , and strawberry and cherry hard candy . xxmaj the fruit is backed with ample tannin , and a warm touch of mocha and toast fills in the finish . xxbos xxmaj high xxmaj purple xxmaj star 2009 xxmaj cabernet xxmaj sauvignon ( xxmaj columbia xxmaj valley ( xxup wa ) ) xxmaj this is made</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>xxmaj dark - skinned berry , underbrush and leather aromas lead the nose . xxmaj the palate is firm , offering plum , toast , mocha and tobacco flavors , while assertive tannins leave a taut finish . xxbos xxmaj medium xxup v. xxmaj sattui 2011 xxmaj secco xxmaj riesling ( xxmaj napa xxmaj valley ) xxmaj it 's called xxmaj secco , according to the winery , because it</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>alorna 2016 xxmaj vinho xxmaj branco xxmaj white ( xxmaj tejo ) xxmaj this blend of xxmaj fernão xxmaj pires , xxmaj arinto , xxmaj sauvignon xxmaj blanc and , unusually , xxmaj marsanne is ripe , with a deliciously perfumed character . xxmaj acidity and bright fruit give crispness that contrasts with the rich texture . xxmaj drink from 2018 . xxbos xxmaj high xxmaj finca xxmaj flichman 2009</td>
#     </tr>
#   </tbody>
# </table>

# %%
languageModel6 = language_model_learner(train_data_lm6, arch=AWD_LSTM, pretrained_fnames=fnames, drop_mult=0.3)

# %%
languageModel6.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='1587' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.24% [99/1587 00:13<03:19 8.4018]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
languageModel6.recorder.plot(skip_end=10)

# %%
languageModel6.fit_one_cycle(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.768517</td>
#       <td>2.648152</td>
#       <td>0.478621</td>
#       <td>03:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.655008</td>
#       <td>2.544396</td>
#       <td>0.489169</td>
#       <td>03:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.519905</td>
#       <td>2.464957</td>
#       <td>0.499422</td>
#       <td>03:40</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.424839</td>
#       <td>2.403240</td>
#       <td>0.508065</td>
#       <td>03:40</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.317748</td>
#       <td>2.390044</td>
#       <td>0.509571</td>
#       <td>03:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
#languageModel2.save('fine_tuned2')
languageModel6.save_encoder('fine_tuned_enc6')

# %% [markdown]
# # Classifier Model 6

# %%
data_classifier6 = (TextList.from_df(df=train_data,path='.',cols='all_text_combined4', vocab=train_data_lm6.vocab)
                    .split_by_rand_pct(0.1)
                    .label_from_df('variety')
                    .add_test(test_data)
                    .databunch(bs=48))

# %%
data_classifier6.save('data_classifier6.pkl')

# %%
data_classifier6 = load_data('','data_classifier6.pkl',bs=48)

# %%
data_classifier6.show_batch(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj low xxmaj meander 2006 xxmaj morisoli xxmaj vineyard xxmaj cabernet xxmaj sauvignon ( xxmaj rutherford ) xxmaj this very fine xxmaj cabernet wants a little time in the cellar . xxmaj right now , it 's tight in tannins , with some acidic bitterness in the finish . xxmaj the flavors are of black currants and smoky new oak . xxmaj the xxmaj morisoli xxmaj vineyard has been</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj medium xxmaj mullineux 2013 xxmaj cape xxmaj winemakers xxmaj guild xxmaj trifecta xxmaj syrah ( xxmaj swartland ) xxmaj winemaker : xxmaj andrea xxmaj mullineux . xxmaj named xxmaj trifecta for the three vineyards — one schist - based , one granite - based and one iron - based — the wine is sourced from , this is an expressive and layered xxmaj syrah . xxmaj initial notes</td>
#       <td>Syrah</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj low xxmaj woodward xxmaj canyon 2012 xxmaj old xxmaj vines xxmaj cabernet xxmaj sauvignon ( xxmaj washington ) a blend of xxmaj champoux ( 62 % ) , xxmaj sagemoor ( 26 % ) and xxmaj woodward xxmaj canyon ( 12 % ) estate vineyards , this wine is aromatically brooding at present , with notes of coffee , toffee and vanilla bean alongside high - toned cherries</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj medium xxmaj mvemve xxmaj raats 2012 xxup mr de xxmaj compostella xxmaj red ( xxmaj stellenbosch ) a blend of 28 % xxmaj cabernet xxmaj franc , 23 % xxmaj cabernet xxmaj sauvignon , 21 % xxmaj malbec , 18 % xxmaj petit xxmaj verdot and 10 % xxmaj merlot , this is a big , bold and powerful wine , with superb balance and a firm ,</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj low xxmaj betz xxmaj family 2012 xxmaj le xxmaj parrain xxmaj cabernet xxmaj sauvignon ( xxmaj red xxmaj mountain ) a rare reserve - level xxmaj cabernet only made once before , this 100 % varietal wine hails from esteemed xxmaj kiona and xxmaj ciel du xxmaj cheval vineyards . xxmaj char and dark roasted coffee aromas meld with notes of herbs , spice and black fruit .</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel6 = text_classifier_learner(data_classifier6, arch=AWD_LSTM, drop_mult=0.5,metrics = [accuracy])
classifierModel6.load_encoder('fine_tuned_enc6')
classifierModel6.freeze()

# %%
classifierModel6.summary()
# Out:
# SequentialRNN
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# RNNDropout           [57, 400]            0          False
# ______________________________________________________________________
# RNNDropout           [57, 1152]           0          False
# ______________________________________________________________________
# RNNDropout           [57, 1152]           0          False
# ______________________________________________________________________
# BatchNorm1d          [1200]               2,400      True
# ______________________________________________________________________
# Dropout              [1200]               0          False
# ______________________________________________________________________
# Linear               [50]                 60,050     True
# ______________________________________________________________________
# ReLU                 [50]                 0          False
# ______________________________________________________________________
# BatchNorm1d          [50]                 100        True
# ______________________________________________________________________
# Dropout              [50]                 0          False
# ______________________________________________________________________
# Linear               [28]                 1,428      True
# ______________________________________________________________________
#
# Total params: 63,978
# Total trainable params: 63,978
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied
#     RNNTrainer

# %%
classifierModel6.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='95' class='' max='1549' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.13% [95/1549 00:14<03:46 7.6276]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
classifierModel6.recorder.plot()

# %%
classifierModel6.fit_one_cycle(1, 2e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.777323</td>
#       <td>0.353741</td>
#       <td>0.890381</td>
#       <td>02:52</td>
#     </tr>
#   </tbody>
# </table>

# %%
for i in range(2,5):
    classifierModel6.freeze_to(-i)
    classifierModel6.fit_one_cycle(1,slice((1*10**-i)/(2.6**4),1*10**-i))
    print ('')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.158159</td>
#       <td>0.084138</td>
#       <td>0.971809</td>
#       <td>02:58</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.123295</td>
#       <td>0.072782</td>
#       <td>0.975560</td>
#       <td>02:58</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.105100</td>
#       <td>0.071381</td>
#       <td>0.975681</td>
#       <td>03:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
classifierModel6.recorder.plot_losses()

# %%
classifierModel6.save('classifierModel6')

# %%
train_loss6,train_accuracy6 = classifierModel6.validate(classifierModel6.data.train_dl)

# %%
valid_loss6,valid_accuracy6 = classifierModel6.validate(classifierModel6.data.valid_dl)

# %%
print("Training Accuracy from model 6 is {0}".format(train_accuracy6*100))
print('')
print("Validation Accuracy from model 6 is {0}".format(valid_accuracy6*100))
# Out:
# Training Accuracy from model 6 is 97.71626281738281
#
# Validation Accuracy from model 6 is 97.56806182861328

# %%
classifierModel6.show_results(rows=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj low xxmaj domaine xxmaj zind - xxmaj humbrecht 2015 xxmaj clos xxmaj saint xxmaj urbain xxmaj rangen de xxmaj thann xxmaj grand xxmaj cru xxmaj riesling ( xxmaj alsace ) xxmaj smoke , orange , wet stone and earth notes are powerful and beguiling on the nose . xxmaj the palate has absolute concentration and energy and more of that smoky promise . xxmaj this is like the</td>
#       <td>Riesling</td>
#       <td>Riesling</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj medium xxmaj domaine xxup g. xxmaj metz 2014 xxmaj muenchberg xxmaj grand xxmaj cru xxmaj riesling ( xxmaj alsace ) xxmaj this combination of tingling grapefruit spice , pure lemon and leafy lemon balm on the nose is utterly disarming . xxmaj the touch of green apple makes it even more alluring . xxmaj the palate xxunk all of these fresh , lithe , bright and appetizing flavors</td>
#       <td>Riesling</td>
#       <td>Riesling</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj medium xxmaj ernie xxmaj els 2014 xxmaj cape xxmaj winemakers xxmaj guild xxup cwg xxmaj red ( xxmaj stellenbosch ) xxmaj winemaker : xxmaj louis xxmaj xxunk . xxmaj this xxmaj cabernet xxmaj sauvignon - dominant blend , with 30 % xxmaj shiraz and 10 % xxmaj merlot , opens with a lovely mélange of just - ripe aromas of blackberry , cassis and black plum , laced</td>
#       <td>Red Blend</td>
#       <td>Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj medium xxmaj ebner - xxmaj ebenauer 2008 xxmaj blanc de xxmaj blancs xxmaj chardonnay ( xxmaj österreichischer xxmaj sekt ) xxmaj the sumptuous nose immediately signals that this is a special treat : layers of fresh and dried apple melded into autolytic notes of fresh brioche , challah and almond - crusted pastry . xxmaj while the flavors of the palate remain equally sumptuous — introducing an almost</td>
#       <td>Chardonnay</td>
#       <td>Chardonnay</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj low xxmaj piper - xxmaj heidsieck xxup nv xxmaj special xxmaj cuvée xxmaj brut ( xxmaj champagne ) xxmaj the extraordinary package , created by fashion designer xxmaj jean - xxmaj paul xxmaj xxunk , is so over - the - top that it is truly worth xxunk in and of itself . a hand - stitched , red vinyl body suit , tailored to the bottle ’s</td>
#       <td>Champagne Blend</td>
#       <td>Champagne Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj medium xxmaj cave de xxmaj ribeauvillé 2010 xxmaj gloeckelberg xxmaj grand xxmaj cru xxmaj pinot xxmaj gris ( xxmaj alsace ) xxmaj the nose already promises both texture and ripeness with its combined aroma of russet pear peel and juicy pear flesh . xxmaj the palate only adds to the juicy richness with a good dollop of residual sweetness , boosting all of the pear fruit . xxmaj</td>
#       <td>Pinot Gris</td>
#       <td>Pinot Gris</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj low xxmaj leonetti xxmaj cellar 2014 xxmaj reserve xxmaj red ( xxmaj walla xxmaj walla xxmaj valley ( xxup wa ) ) xxmaj this wine is a blend of 79 % xxmaj cabernet xxmaj sauvignon , 13 % xxmaj malbec and 8 % xxmaj petit xxmaj verdot from xxmaj seven xxmaj hills , xxmaj loess , xxmaj mill xxmaj creek xxmaj upland and xxmaj serra xxmaj pedace vineyards</td>
#       <td>Bordeaux-style Red Blend</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj medium xxmaj biecher &amp; xxmaj schaal 2015 xxmaj rangen de xxmaj thann xxmaj grand xxmaj cru xxmaj riesling ( xxmaj alsace ) a lovely touch of flint and smoke carry a touch of residual reduction . xxmaj underneath that is lemony purity . xxmaj the palate adds a touch of stone fruit , a touch of ripe mirabelle plum — its generosity only underlined by the taut lemon</td>
#       <td>Riesling</td>
#       <td>Riesling</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj low xxmaj trefethen 2008 halo xxmaj cabernet xxmaj sauvignon ( xxmaj oak xxmaj knoll xxmaj district ) xxmaj trefethen has been on a roll the last few years , producing some of xxmaj napa 's most spectacular xxmaj cabernets . xxmaj this bottling , which contains minor quantities of xxmaj petit xxmaj verdot and xxmaj merlot , spent 28 months in new xxmaj french oak barrels . xxmaj</td>
#       <td>Cabernet Sauvignon</td>
#       <td>Cabernet Sauvignon</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj medium xxmaj rodney xxmaj strong 2004 xxmaj symmetry xxmaj meritage xxmaj red ( xxmaj alexander xxmaj valley ) xxmaj strong 's xxmaj symmetry almost qualifies as a xxmaj cabernet xxmaj sauvignon , with 71 % of that variety , and the rest consisting of xxmaj merlot , xxmaj malbec and xxmaj petit xxmaj verdot . xxmaj the xxmaj meritage labeling identifies it as their supreme bottling of a</td>
#       <td>Bordeaux-style Red Blend</td>
#       <td>Bordeaux-style Red Blend</td>
#     </tr>
#   </tbody>
# </table>

# %%
preds6 = classifierModel6.get_preds(DatasetType.Test)

# %%
build_submission_file(classifierModel6,preds6,'submission6.csv')
# Out:
#               user_name    country  \
# 0           @paulgwine          US
# 1           @wineschach  Argentina
# 2               @vboone         US
# 3           @wineschach  Argentina
# 4          @kerinokeefe      Italy
# ...                 ...        ...
# 20660  @gordone_cellars         US
# 20661         @laurbuzz     France
# 20662     @mattkettmann         US
# 20663       @wineschach      Spain
# 20664               NaN         US
#
#                                             review_title  \
# 0      Boedecker Cellars 2011 Athena Pinot Noir (Will...
# 1      Mendoza Vineyards 2012 Gran Reserva by Richard...
# 2                    Prime 2013 Chardonnay (Coombsville)
# 3      Bodega Cuarto Dominio 2012 Chento Vineyard Sel...
# 4               SassodiSole 2012  Brunello di Montalcino
# ...                                                  ...
# 20660  Yorkville Cellars 2013 Rennie Vineyard Caberne...
# 20661  Château Ribaute 2015 Senhal d'Aric Rosé (Corbi...
# 20662  Daou 2014 Reserve Cabernet Sauvignon (Paso Rob...
# 20663  Peñascal 2011 Tempranillo Rosé (Vino de la Tie...
# 20664  Langtry 2005 Tephra Ridge Vineyard Cabernet Sa...
#
#                                       review_description  \
# 0      Nicely differentiated from the companion Stewa...
# 1      Charred, smoky, herbal aromas of blackberry tr...
# 2      Slightly sour and funky in earth, this is a re...
# 3      This concentrated, midnight-black Malbec deliv...
# 4      Earthy aromas suggesting grilled porcini, leat...
# ...                                                  ...
# 20660  Clearly focused and fruit-driven, this wine ha...
# 20661  Herbal tones of bay and rosemary are upfront o...
# 20662  Mocha cream, pencil shaving and dried herb aro...
# 20663  Loud citrus and berry aromas precede an overlo...
# 20664  With very ripe fruit and firm tannins, this mo...
#
#                           designation  points  price              province  \
# 0                              Athena      88   35.0                Oregon
# 1      Gran Reserva by Richard Bonvin      90   60.0      Mendoza Province
# 2                                 NaN      87   38.0            California
# 3           Chento Vineyard Selection      91   20.0      Mendoza Province
# 4                                 NaN      90   49.0               Tuscany
# ...                               ...     ...    ...                   ...
# 20660                 Rennie Vineyard      91   34.0            California
# 20661                   Senhal d'Aric      84   20.0  Languedoc-Roussillon
# 20662                         Reserve      94   85.0            California
# 20663                     Tempranillo      80    9.0        Northern Spain
# 20664           Tephra Ridge Vineyard      87   40.0            California
#
#                                    region_1           region_2  \
# 0                         Willamette Valley  Willamette Valley
# 1                                   Mendoza                NaN
# 2                               Coombsville               Napa
# 3                                   Mendoza                NaN
# 4                    Brunello di Montalcino                NaN
# ...                                     ...                ...
# 20660                   Yorkville Highlands        North Coast
# 20661                             Corbières                NaN
# 20662                           Paso Robles      Central Coast
# 20663  Vino de la Tierra de Castilla y León                NaN
# 20664                           Lake County                NaN
#
#                       winery             variety
# 0          Boedecker Cellars          Pinot Noir
# 1          Mendoza Vineyards              Malbec
# 2                      Prime          Chardonnay
# 3      Bodega Cuarto Dominio              Malbec
# 4                SassodiSole          Sangiovese
# ...                      ...                 ...
# 20660      Yorkville Cellars      Cabernet Franc
# 20661        Château Ribaute                Rosé
# 20662                   Daou  Cabernet Sauvignon
# 20663               Peñascal                Rosé
# 20664                Langtry  Cabernet Sauvignon
#
# [20665 rows x 12 columns]

# %%
#classifierModel6.unfreeze()
#classifierModel6.fit_one_cycle(1, slice(1e-5/(2.6**4),1e-3))

# %%
models =['ClassifierModel1',
         'ClassifierModel2',
         'ClassifierModel3',
         'ClassifierModel4',
         'ClassifierModel5',
         'ClassifierModel6']
cols = ['Training Accuracy',
        'Training Loss',
        'Validation Accuracy',
        'Validation Loss']
                                       
final_results = pd.DataFrame(columns = cols,index=models)

# %%
final_results[cols[0]][models[0]] = train_accuracy1*100
final_results[cols[1]][models[0]] = train_loss1
final_results[cols[2]][models[0]] = valid_accuracy1*100
final_results[cols[3]][models[0]] = valid_loss1

final_results[cols[0]][models[1]] = train_accuracy2*100
final_results[cols[1]][models[1]] = train_loss2
final_results[cols[2]][models[1]] = valid_accuracy2*100
final_results[cols[3]][models[1]] = valid_loss2

final_results[cols[0]][models[2]] = train_accuracy3*100
final_results[cols[1]][models[2]] = train_loss3
final_results[cols[2]][models[2]] = valid_accuracy3*100
final_results[cols[3]][models[2]] = valid_loss3

final_results[cols[0]][models[3]] = train_accuracy4*100
final_results[cols[1]][models[3]] = train_loss4
final_results[cols[2]][models[3]] = valid_accuracy4*100
final_results[cols[3]][models[3]] = valid_loss4

final_results[cols[0]][models[4]] = train_accuracy5*100
final_results[cols[1]][models[4]] = train_loss5
final_results[cols[2]][models[4]] = valid_accuracy5*100
final_results[cols[3]][models[4]] = valid_loss5


final_results[cols[0]][models[5]] = train_accuracy6*100
final_results[cols[1]][models[5]] = train_loss6
final_results[cols[2]][models[5]] = valid_accuracy6*100
final_results[cols[3]][models[5]] = valid_loss6

# %%
print("Final results")
print('')
print(final_results)
# Out:
# Final results
#
#                  Training Accuracy Training Loss Validation Accuracy  \
# ClassifierModel1   tensor(76.7000)       0.72535     tensor(76.6691)
# ClassifierModel2   tensor(97.7566)     0.0639339     tensor(97.3987)
# ClassifierModel3   tensor(97.7876)     0.0624435     tensor(97.5318)
# ClassifierModel4   tensor(97.8333)     0.0605756     tensor(97.7374)
# ClassifierModel5   tensor(97.8951)     0.0585178     tensor(97.8221)
# ClassifierModel6   tensor(97.7163)     0.0621578     tensor(97.5681)
#
#                  Validation Loss
# ClassifierModel1        0.725286
# ClassifierModel2       0.0713948
# ClassifierModel3       0.0729472
# ClassifierModel4       0.0657355
# ClassifierModel5       0.0629165
# ClassifierModel6       0.0713805

# %% [markdown]
# <font size =6 face ='Times New Roman' color = #800080 line-height: 40px>Model 5 gives the best validation accuracy</font>

# %%
f,ax = plt.subplots(figsize = (20,20))
sns.pointplot(final_results.index,final_results['Validation Accuracy'])
plt.xticks(fontsize =15)
plt.yticks(fontsize =15)
plt.xlabel("Wines",fontsize =20)
plt.ylabel("Models",fontsize =20,rotation = 0)
plt.title('Validation Accuracy', fontsize=25)
plt.grid(True)
plt.show()
